# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import unicodedata
import re
import numpy as np
import os
import time
import pandas as pd
from sklearn.model_selection import train_test_split

from pylab import *
from matplotlib.font_manager import FontProperties
print('tf.__version__.is', tf.__version__)
print('tf.keras.__version__ is:', tf.keras.__version__)
print(tf.config.experimental.list_physical_devices('GPU'))
# Out:
# tf.__version__.is 2.5.0
# tf.keras.__version__ is: 2.5.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# Dataset loading

# %%
tcn_clean = pd.read_csv('./preprocessed/cleaned_dev_tcn.csv')
tcn_clean
# Out:
#                                                   text    split  \
# 0                  OPPO A75 A75s A73 手机壳 软壳 挂绳壳 大眼兔硅胶壳  private
# 1                                  SOFT 99 鍍膜車蠟(強力撥水型)  private
# 2                                       低糖芒果乾 250g 臻御行  private
# 3    ＊小徑文化＊日本進口ROUND TOP space craft - diamond (SC-...  private
# 4            Hello Kitty 凱蒂貓 KITTY 涼鞋 童鞋 白/紅色 小童 no739  private
# ..                                                 ...      ...
# 995                【HippoRed】撕破乐趣★独特风格★中直筒牛仔裤 O591_445  private
# 996                      兒童套裝 台灣製薄長袖居家套裝 魔法Baby~k60092  private
# 997                 LONGCHAMP Le Pliage Neo高密尼龍後背包(中型)  private
# 998            iFairies 開口可調節戒指★ifairies【56472】【56472】  private
# 999                        PolarStar 女 排汗快干T恤『黑』P18102  private
#
#     product_title_clean     product_title_processed
# 0        手机壳软壳挂绳壳大眼兔硅胶壳      手机 壳 软壳 挂绳 壳 大眼 兔 硅胶 壳
# 1             鍍膜車蠟強力撥水型                鍍膜車 蠟 強力 撥水型
# 2              低糖芒果乾臻御行                 低糖 芒果乾 臻 御行
# 3              小徑文化日本進口                 小徑 文化 日本 進口
# 4          凱蒂貓涼鞋童鞋白紅色小童            凱蒂貓 涼鞋 童鞋 白紅色 小童
# ..                  ...                         ...
# 995      撕破乐趣独特风格中直筒牛仔裤        撕破 乐趣 独特 风格 中直 筒 牛仔裤
# 996    兒童套裝台灣製薄長袖居家套裝魔法  兒童 套 裝台 灣 製 薄 長 袖 居家 套裝 魔法
# 997           高密尼龍後背包中型               高密 尼龍 後 背包 中型
# 998             開口可調節戒指                  開口 可 調節 戒指
# 999             女排汗快干恤黑                 女排 汗 快干 恤 黑
#
# [1000 rows x 4 columns]

# %%
en_clean = pd.read_csv('./preprocessed/cleaned_dev_en.csv')
en_clean
# Out:
#                                     translation_output
# 0            oppo phone case soft rabbit silicone case
# 1               soft coating car wax strong water watt
# 2                     low sugar mango dry be the royal
# 3    the culture japan imported round top space cra...
# 4         hello kitty sandals shoes white red children
# ..                                                 ...
# 995      hippored torn fun unique style straight jeans
# 996  kids set table bay thin long sleeve home suit ...
# 997  longchamp le pliage neo high density nylon bac...
# 998          ifairies opening adjustable ring ifairies
# 999      polarstar women sweat quick dry t shirt black
#
# [1000 rows x 1 columns]

# %% [markdown]
# Preprocessing (change from unicode to ascii & add \<start\> and \<end\> tokens

# %%
def unicode_to_ascii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
                   if unicodedata.category(c) != 'Mn')

# %%
def preprocess(w):
    w = unicode_to_ascii(w.lower().strip())

    # adding a start and an end token to the sentence
    # so that the model know when to start and stop predicting.
    w = '<start> ' + w + ' <end>'
    return w

# %%
# u means unicode encoder
en_sentence = en_clean['translation_output'][0]
chn_sentence = tcn_clean['product_title_processed'][0]
print(preprocess(en_sentence))
print(preprocess(chn_sentence))
print(preprocess(chn_sentence).encode('utf-8'))
# Out:
# <start> oppo phone case soft rabbit silicone case <end>
# <start> 手机 壳 软壳 挂绳 壳 大眼 兔 硅胶 壳 <end>
# b'<start> \xe6\x89\x8b\xe6\x9c\xba \xe5\xa3\xb3 \xe8\xbd\xaf\xe5\xa3\xb3 \xe6\x8c\x82\xe7\xbb\xb3 \xe5\xa3\xb3 \xe5\xa4\xa7\xe7\x9c\xbc \xe5\x85\x94 \xe7\xa1\x85\xe8\x83\xb6 \xe5\xa3\xb3 <end>'

# %% [markdown]
# Prepare Embedding Layer

# %%
def create_dataset(target, source):
    assert len(source) == len(target)
    word_pairs = [[preprocess(str(target[i])), preprocess(str(source[i]))]
                  for i in range(len(source))]

    # return two tuple: one tuple includes all English sentenses, and 
    # another tuple includes all Chinese sentenses
    return word_pairs

word_pairs = create_dataset(en_clean['translation_output'], tcn_clean['product_title_processed'])
word_pairs[:20]
# Out:
# [['<start> oppo phone case soft rabbit silicone case <end>',
#   '<start> 手机 壳 软壳 挂绳 壳 大眼 兔 硅胶 壳 <end>'],
#  ['<start> soft coating car wax strong water watt <end>',
#   '<start> 鍍膜車 蠟 強力 撥水型 <end>'],
#  ['<start> low sugar mango dry be the royal <end>',
#   '<start> 低糖 芒果乾 臻 御行 <end>'],
#  ['<start> the culture japan imported round top space craft diamond sc mk <end>',
#   '<start> 小徑 文化 日本 進口 <end>'],
#  ['<start> hello kitty sandals shoes white red children <end>',
#   '<start> 凱蒂貓 涼鞋 童鞋 白紅色 小童 <end>'],
#  ['<start> thunderbird lt japanese wood grain table mat x cm pc <end>',
#   '<start> 雷鳥 日式 木紋 桌墊片 <end>'],
#  ['<start> the sand kid dvd vol <end>', '<start> 狂砂 小子 <end>'],
#  ['<start> anacomda python titan series ssd drive <end>',
#   '<start> 巨蟒 泰坦 系列 固態 硬碟 <end>'],
#  ['<start> ifairies shoulder messenger bag shoulder bag <end>',
#   '<start> 單肩 斜 背包 側 背包 肩 背包 <end>'],
#  ['<start> the farm mountain bitter gourd tea pack box <end>',
#   '<start> 大雪山 農場 山 苦瓜 茶 包盒 <end>'],
#  ['<start> colgate dual clean toothbrush <end>',
#   '<start> 高露潔 雙效潔淨 牙刷 單支 <end>'],
#  ['<start> apieu color lip pencil matt silk satin <end>', '<start> 絲緞 <end>'],
#  ['<start> reese s away milan rose gold ball pen <end>',
#   '<start> 芮菲 客米蘭 玫瑰 金鋼 珠筆 <end>'],
#  ['<start> finding nemo glass magnet dolly _ the beast <end>',
#   '<start> 海底 總動員 玻璃 磁鐵多莉款 野獸國 <end>'],
#  ['<start> natural licorice oval pumpkin seeds <end>',
#   '<start> 甘草 瓜子 南瓜子 <end>'],
#  ['<start> papago hd driving recorder <end>', '<start> 行車 記錄器 <end>'],
#  ['<start> ista izmir the mesh head <end>', '<start> 伊士 達 分濾 網頭 <end>'],
#  ['<start> dot focus adidas essentials chest logo square box gray blue hooded men <end>',
#   '<start> 聚點 方形 方塊 灰 藍連帽 帽 男款 <end>'],
#  ['<start> tassel solid thread moka one blue black <end>',
#   '<start> 流蘇立體 縫線 莫卡 辛鞋 藍 黑色 <end>'],
#  ['<start> new fashion cute baby embroidery dress <end>',
#   '<start> 新品 時 尚可 愛寶寶繡 花連 衣裙 洋裝 <end>']]

# %%
en, chn = zip(*create_dataset(en_clean['translation_output'], tcn_clean['product_title_processed']))
print(en[-1])
print(chn[-1])
# show the size of the dataset
assert len(en) == len(chn)
print("Size:", len(en))
# Out:
# <start> polarstar women sweat quick dry t shirt black <end>
# <start> 女排 汗 快干 恤 黑 <end>
# Size: 1000

# %%
def tokenize(lang):
    lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
        filters='')
    # generate a dictionary, e.g. word -> index(of the dictionary)
    lang_tokenizer.fit_on_texts(lang)

    # output the vector sequences, e.g. [1, 7, 237, 3, 2]
    tensor = lang_tokenizer.texts_to_sequences(lang)

    # padding sentences to the same length
    tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                           padding='post')
    return tensor, lang_tokenizer

# %%
def load_dataset(target, source):
    # creating cleaned input, output pairs
    # regard Chinese as source sentence, regard English as target sentence
    targ_lang, inp_lang = zip(*create_dataset(target, source))

    input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
    target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

    return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %%
def max_length(tensor):
    # padding the sentence to max_length
    return max(len(t) for t in tensor)

# %%
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(en_clean['translation_output'], 
                                                                tcn_clean['product_title_processed'])

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = max_length(
    target_tensor), max_length(input_tensor)

# Creating training and validation sets using an 95-5 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(
    input_tensor, target_tensor, test_size=0.05)

# Show length of the training data and validation data
print("# training data: {:d}\n# test data: {:d}".format(len(input_tensor_train), len(input_tensor_val)))
# Out:
# # training data: 950
# # test data: 50

# %%
def convert(lang, tensor):
    for t in tensor:
        if t != 0:
            print("%d ----> %s" % (t, lang.index_word[t]))

print("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print()
print("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 627 ----> 樹德
# 58 ----> 多功能
# 2375 ----> 置物櫃
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 589 ----> tree
# 390 ----> de
# 384 ----> sc
# 327 ----> multifunctional
# 2017 ----> locker
# 2 ----> <end>

# %% [markdown]
# Initialise Parameters

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 128
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 256
units = 1024
# 0 is a reserved index that won't be assigned to any word, so the size of vocabulary should add 1
vocab_inp_size = len(inp_lang.word_index) + 1
vocab_tar_size = len(targ_lang.word_index) + 1

dataset = tf.data.Dataset.from_tensor_slices(
    (input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# (TensorShape([128, 18]), TensorShape([128, 17]))

# %%
print('vocab_inp_size =', vocab_inp_size)
print('vocab_tar_size =', vocab_tar_size)
# Out:
# vocab_inp_size = 3224
# vocab_tar_size = 2494

# %% [markdown]
# Encoder class construction

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        # vacab_size=vocab_inp_size=3224, embedding_dim=256 enc_units=1024 batch_sz=128
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.enc_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_activation='sigmoid',
                                       recurrent_initializer='glorot_uniform')

    def call(self, x, hidden):
        # x is the training data with shape == (batch_size, max_length)  -> (128, 18)
        # which means there are batch_size sentences in one batch, the length of each sentence is max_length
        # hidden state shape == (batch_size, units) -> (128, 1024)
        # after embedding, x shape == (batch_size, max_length, embedding_dim) -> (128, 18, 256)
        x = self.embedding(x)
        
        # output contains the state(in GRU, the hidden state and the output are same) from all timestamps,
        # output shape == (batch_size, max_length, units) -> (128, 18, 1024)
        # state is the hidden state of the last timestamp, shape == (batch_size, units) -> (128, 1024)
        output, state = self.gru(x, initial_state=hidden)
        
        return output, state

    def initialize_hidden_state(self):
        # initialize the first state of the gru,  shape == (batch_size, units) -> (128, 1024)
        return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)
print('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))

# the output and the hidden state of GRU is equal
print(sample_output[-1, -1, :] == sample_hidden[-1, :])
# Out:
# Encoder output shape: (batch size, sequence length, units) (128, 18, 1024)
# Encoder Hidden state shape: (batch size, units) (128, 1024)
# tf.Tensor([ True  True  True ...  True  True  True], shape=(1024,), dtype=bool)

# %% [markdown]
# Define Attention layer

# %%
class BahdanauAttention(tf.keras.Model):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)

    def call(self, query, values):
        # query shape == (batch_size, hidden size)
        # hidden_with_time_axis shape == (batch_size, 1, hidden size)
        # we are doing this to perform addition to calculate the score
        hidden_with_time_axis = tf.expand_dims(query, 1)

        # score shape == (batch_size, max_length, 1)
        # we get 1 at the last axis because we are applying score to self.V
        # the shape of the tensor before applying self.V is (batch_size, max_length, units)
        score = self.V(tf.nn.tanh(self.W1(values) + self.W2(hidden_with_time_axis)))

        # attention_weights shape == (batch_size, max_length, 1)
        attention_weights = tf.nn.softmax(score, axis=1)

        # context_vector shape == (batch_size, max_length, hidden_size)
        context_vector = attention_weights * values
        
        # context_vector shape after sum == (batch_size, hidden_size)
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %%
attention_layer = BahdanauAttention(10)
attention_result, attention_weights = attention_layer(sample_hidden, sample_output)

print("Attention result shape: (batch size, units) {}".format(attention_result.shape))
print("Attention weights shape: (batch_size, sequence_length, 1) {}".format(attention_weights.shape))
# Out:
# Attention result shape: (batch size, units) (128, 1024)
# Attention weights shape: (batch_size, sequence_length, 1) (128, 18, 1)

# %% [markdown]
# Decoder class construction

# %%
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        # vocab_size=vocab_tar_size=2494, embedding_dim=256, dec_units=1024, batch_sz=128
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.dec_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        # the dimension of the output is the vocab size, through the softmax function,
        # this layer will return the probability of each word in the dictory
        self.fc = tf.keras.layers.Dense(vocab_size)

        # used for attention
        self.attention = BahdanauAttention(self.dec_units)

    def call(self, x, hidden, enc_output):
        # This function outputs a result at each timestamp
        # The hidden state of fisrt timestamp in the decoder is 
        # the hidden state of last timestamp in the encoder
        context_vector, attention_weights = self.attention(hidden, enc_output)
        
        # x shape after passing through embedding == (batch_size, 1, embedding_dim)
        x = self.embedding(x)

        # concatenate the input x and the context_vector, as the input of the GRU
        # context_vector shape == (batch_size, units) -> (128, 1024)
        # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size) -> (128, 1, 1024 + 256)
        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

        # passing the concatenated vector to the GRU
        # get the output and state of the current timestamp
        # output shape == (batch_size, 1, units) -> (128, 1, 1024) 
        # state shape == (batch_size, units) -> (128, 1024)
        output, state = self.gru(x)

        # output shape == (batch_size, hidden_size) -> (128, 1024)
        output = tf.reshape(output, (-1, output.shape[2]))

        # output shape == (batch_size, vocab) -> (128, 2494)
        x = self.fc(output)

        return x, state, attention_weights

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)
sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)), sample_hidden, sample_output)
print('Decoder output shape: (batch_size, vocab size) {}'.format(sample_decoder_output.shape))
# Out:
# Decoder output shape: (batch_size, vocab size) (128, 2494)

# %% [markdown]
# Define optimizer and loss function

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

def loss_function(real, pred):
    """Calculate the loss value
    Args:
        real: the true label  shape == (batch_size,) -> (128,)
        pred: the probability of each word from the vocabulary, is the output from the decoder 
                 shape == (batch_size, vocab_size) -> (128, 6082)

    Returns: 
        the average loss of the data in a batch size
    """
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %% [markdown]
# Checkpoints saving

# %%
checkpoint_dir = './checkpoints/tcn-eng'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %% [markdown]
# Define Training

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
    loss = 0

    with tf.GradientTape() as tape:
        enc_output, enc_hidden = encoder(inp, enc_hidden)

        dec_hidden = enc_hidden
        
        # feed the <start> as the first input of the decoder
        # dec input shape == (batch_size, 1) -> (128, 1)
        dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

        # Teacher forcing - feeding the target as the next input
        # because of the data preprocessing(add a start token to the sentence)
        # the first word is <start>, so t starts from 1(not 0)
        for t in range(1, targ.shape[1]):
            # passing enc_output to the decoder
            predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

            # targ[:, t] is the true label(index of the word) of every sentence(in a batch) 
            # at the current timestamp
            # like [  85   18   25   25  ···  1047   79   13], shape == (batch_size,) -> (128,)
            # predictions shape == (batch_size, vocab_size) -> (128, 6082)
            loss += loss_function(targ[:, t], predictions)

            # using teacher forcing
            dec_input = tf.expand_dims(targ[:, t], 1)

    batch_loss = (loss / int(targ.shape[1]))

    # collect all trainable variables
    variables = encoder.trainable_variables + decoder.trainable_variables

    # calculate the gradients for the whole variables
    gradients = tape.gradient(loss, variables)

    # apply the gradients on the variables
    optimizer.apply_gradients(zip(gradients, variables))

    return batch_loss

# %%
EPOCHS = 100

for epoch in range(EPOCHS):
    start = time.time()

    # get the initial hidden state of gru
    enc_hidden = encoder.initialize_hidden_state()
    total_loss = 0

    for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
        batch_loss = train_step(inp, targ, enc_hidden)
        total_loss += batch_loss

        if batch % 100 == 0:
            print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                         batch,
                                                         batch_loss.numpy()))

    # saving (checkpoint) the model every 5 epochs
    if (epoch + 1) % 5 == 0:
        checkpoint.save(file_prefix=checkpoint_prefix)
        
    print('Epoch {} Loss {:.4f}'.format(epoch + 1, total_loss / steps_per_epoch))
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 3.8462
# Epoch 1 Loss 3.9231
# Time taken for 1 epoch 12.249014854431152 sec
#
# Epoch 2 Batch 0 Loss 3.7581
# Epoch 2 Loss 3.8169
# Time taken for 1 epoch 0.8281874656677246 sec
#
# Epoch 3 Batch 0 Loss 3.6186
# Epoch 3 Loss 3.5939
# Time taken for 1 epoch 0.83418869972229 sec
#
# Epoch 4 Batch 0 Loss 3.5620
# Epoch 4 Loss 3.4410
# Time taken for 1 epoch 0.8471908569335938 sec
#
# Epoch 5 Batch 0 Loss 3.2814
# Epoch 5 Loss 3.3679
# Time taken for 1 epoch 1.2900452613830566 sec
#
# Epoch 6 Batch 0 Loss 3.3001
# Epoch 6 Loss 3.3165
# Time taken for 1 epoch 0.8521928787231445 sec
#
# Epoch 7 Batch 0 Loss 3.2400
# Epoch 7 Loss 3.2776
# Time taken for 1 epoch 0.8411896228790283 sec
#
# Epoch 8 Batch 0 Loss 3.3699
# Epoch 8 Loss 3.2398
# Time taken for 1 epoch 0.8321881294250488 sec
#
# Epoch 9 Batch 0 Loss 3.1656
# Epoch 9 Loss 3.1906
# Time taken for 1 epoch 0.8391892910003662 sec
#
# Epoch 10 Batch 0 Loss 3.2210
# Epoch 10 Loss 3.1261
# Time taken for 1 epoch 1.2377955913543701 sec
#
# Epoch 11 Batch 0 Loss 3.0112
# Epoch 11 Loss 3.0936
# Time taken for 1 epoch 0.8371880054473877 sec
#
# Epoch 12 Batch 0 Loss 3.0023
# Epoch 12 Loss 3.0469
# Time taken for 1 epoch 0.8421900272369385 sec
#
# Epoch 13 Batch 0 Loss 2.8855
# Epoch 13 Loss 2.9997
# Time taken for 1 epoch 0.8431906700134277 sec
#
# Epoch 14 Batch 0 Loss 2.9913
# Epoch 14 Loss 2.9592
# Time taken for 1 epoch 0.8501923084259033 sec
#
# Epoch 15 Batch 0 Loss 2.8341
# Epoch 15 Loss 2.8804
# Time taken for 1 epoch 1.2788457870483398 sec
#
# Epoch 16 Batch 0 Loss 2.7995
# Epoch 16 Loss 2.8236
# Time taken for 1 epoch 0.8351881504058838 sec
#
# Epoch 17 Batch 0 Loss 2.7077
# Epoch 17 Loss 2.7426
# Time taken for 1 epoch 0.8441908359527588 sec
#
# Epoch 18 Batch 0 Loss 2.6270
# Epoch 18 Loss 2.6696
# Time taken for 1 epoch 0.832188606262207 sec
#
# Epoch 19 Batch 0 Loss 2.6539
# Epoch 19 Loss 2.5874
# Time taken for 1 epoch 0.8461902141571045 sec
#
# Epoch 20 Batch 0 Loss 2.5185
# Epoch 20 Loss 2.5203
# Time taken for 1 epoch 1.2331604957580566 sec
#
# Epoch 21 Batch 0 Loss 2.2796
# Epoch 21 Loss 2.4254
# Time taken for 1 epoch 0.8331875801086426 sec
#
# Epoch 22 Batch 0 Loss 2.3175
# Epoch 22 Loss 2.3382
# Time taken for 1 epoch 0.845191240310669 sec
#
# Epoch 23 Batch 0 Loss 2.2388
# Epoch 23 Loss 2.2293
# Time taken for 1 epoch 0.8361897468566895 sec
#
# Epoch 24 Batch 0 Loss 2.0654
# Epoch 24 Loss 2.1217
# Time taken for 1 epoch 0.8341875076293945 sec
#
# Epoch 25 Batch 0 Loss 1.9785
# Epoch 25 Loss 2.0263
# Time taken for 1 epoch 1.2555358409881592 sec
#
# Epoch 26 Batch 0 Loss 1.9680
# Epoch 26 Loss 1.9134
# Time taken for 1 epoch 0.8381896018981934 sec
#
# Epoch 27 Batch 0 Loss 1.8357
# Epoch 27 Loss 1.8001
# Time taken for 1 epoch 0.8501930236816406 sec
#
# Epoch 28 Batch 0 Loss 1.6620
# Epoch 28 Loss 1.6948
# Time taken for 1 epoch 0.8416941165924072 sec
#
# Epoch 29 Batch 0 Loss 1.5389
# Epoch 29 Loss 1.5884
# Time taken for 1 epoch 0.8451905250549316 sec
#
# Epoch 30 Batch 0 Loss 1.5326
# Epoch 30 Loss 1.4940
# Time taken for 1 epoch 1.2515509128570557 sec
#
# Epoch 31 Batch 0 Loss 1.3814
# Epoch 31 Loss 1.3987
# Time taken for 1 epoch 0.8311879634857178 sec
#
# Epoch 32 Batch 0 Loss 1.3492
# Epoch 32 Loss 1.3162
# Time taken for 1 epoch 0.8431899547576904 sec
#
# Epoch 33 Batch 0 Loss 1.2663
# Epoch 33 Loss 1.2499
# Time taken for 1 epoch 0.8571937084197998 sec
#
# Epoch 34 Batch 0 Loss 1.2186
# Epoch 34 Loss 1.1796
# Time taken for 1 epoch 0.8531925678253174 sec
#
# Epoch 35 Batch 0 Loss 1.0938
# Epoch 35 Loss 1.1103
# Time taken for 1 epoch 1.2340388298034668 sec
#
# Epoch 36 Batch 0 Loss 1.0778
# Epoch 36 Loss 1.0571
# Time taken for 1 epoch 0.8351883888244629 sec
#
# Epoch 37 Batch 0 Loss 0.9945
# Epoch 37 Loss 1.0112
# Time taken for 1 epoch 0.838188886642456 sec
#
# Epoch 38 Batch 0 Loss 0.9426
# Epoch 38 Loss 0.9635
# Time taken for 1 epoch 0.8501923084259033 sec
#
# Epoch 39 Batch 0 Loss 0.9394
# Epoch 39 Loss 0.9283
# Time taken for 1 epoch 0.8551931381225586 sec
#
# Epoch 40 Batch 0 Loss 0.8397
# Epoch 40 Loss 0.8959
# Time taken for 1 epoch 1.2369248867034912 sec
#
# Epoch 41 Batch 0 Loss 0.8271
# Epoch 41 Loss 0.8615
# Time taken for 1 epoch 0.8341889381408691 sec
#
# Epoch 42 Batch 0 Loss 0.8323
# Epoch 42 Loss 0.8267
# Time taken for 1 epoch 0.8461906909942627 sec
#
# Epoch 43 Batch 0 Loss 0.7945
# Epoch 43 Loss 0.7876
# Time taken for 1 epoch 0.837693452835083 sec
#
# Epoch 44 Batch 0 Loss 0.7139
# Epoch 44 Loss 0.7568
# Time taken for 1 epoch 0.8391897678375244 sec
#
# Epoch 45 Batch 0 Loss 0.7038
# Epoch 45 Loss 0.7262
# Time taken for 1 epoch 1.5026674270629883 sec
#
# Epoch 46 Batch 0 Loss 0.6742
# Epoch 46 Loss 0.7021
# Time taken for 1 epoch 0.84018874168396 sec
#
# Epoch 47 Batch 0 Loss 0.6760
# Epoch 47 Loss 0.6769
# Time taken for 1 epoch 0.8461906909942627 sec
#
# Epoch 48 Batch 0 Loss 0.6444
# Epoch 48 Loss 0.6521
# Time taken for 1 epoch 0.8631949424743652 sec
#
# Epoch 49 Batch 0 Loss 0.6084
# Epoch 49 Loss 0.6251
# Time taken for 1 epoch 0.8351888656616211 sec
#
# Epoch 50 Batch 0 Loss 0.6266
# Epoch 50 Loss 0.6055
# Time taken for 1 epoch 1.2590534687042236 sec
#
# Epoch 51 Batch 0 Loss 0.5541
# Epoch 51 Loss 0.5775
# Time taken for 1 epoch 0.8771977424621582 sec
#
# Epoch 52 Batch 0 Loss 0.5455
# Epoch 52 Loss 0.5568
# Time taken for 1 epoch 0.9022037982940674 sec
#
# Epoch 53 Batch 0 Loss 0.5239
# Epoch 53 Loss 0.5409
# Time taken for 1 epoch 0.9072062969207764 sec
#
# Epoch 54 Batch 0 Loss 0.4882
# Epoch 54 Loss 0.5229
# Time taken for 1 epoch 0.8771965503692627 sec
#
# Epoch 55 Batch 0 Loss 0.4863
# Epoch 55 Loss 0.5060
# Time taken for 1 epoch 1.2589898109436035 sec
#
# Epoch 56 Batch 0 Loss 0.4665
# Epoch 56 Loss 0.4959
# Time taken for 1 epoch 0.8351881504058838 sec
#
# Epoch 57 Batch 0 Loss 0.4795
# Epoch 57 Loss 0.4742
# Time taken for 1 epoch 0.872197151184082 sec
#
# Epoch 58 Batch 0 Loss 0.4392
# Epoch 58 Loss 0.4583
# Time taken for 1 epoch 0.8581938743591309 sec
#
# Epoch 59 Batch 0 Loss 0.4303
# Epoch 59 Loss 0.4414
# Time taken for 1 epoch 0.8411900997161865 sec
#
# Epoch 60 Batch 0 Loss 0.3867
# Epoch 60 Loss 0.4269
# Time taken for 1 epoch 1.2438085079193115 sec
#
# Epoch 61 Batch 0 Loss 0.4063
# Epoch 61 Loss 0.4135
# Time taken for 1 epoch 0.8361890316009521 sec
#
# Epoch 62 Batch 0 Loss 0.3588
# Epoch 62 Loss 0.4060
# Time taken for 1 epoch 0.847191572189331 sec
#
# Epoch 63 Batch 0 Loss 0.3787
# Epoch 63 Loss 0.3966
# Time taken for 1 epoch 0.8541922569274902 sec
#
# Epoch 64 Batch 0 Loss 0.3620
# Epoch 64 Loss 0.3719
# Time taken for 1 epoch 0.8511922359466553 sec
#
# Epoch 65 Batch 0 Loss 0.3550
# Epoch 65 Loss 0.3534
# Time taken for 1 epoch 1.2526147365570068 sec
#
# Epoch 66 Batch 0 Loss 0.3144
# Epoch 66 Loss 0.3323
# Time taken for 1 epoch 0.8271863460540771 sec
#
# Epoch 67 Batch 0 Loss 0.3042
# Epoch 67 Loss 0.3131
# Time taken for 1 epoch 0.8406937122344971 sec
#
# Epoch 68 Batch 0 Loss 0.2792
# Epoch 68 Loss 0.2953
# Time taken for 1 epoch 0.8421905040740967 sec
#
# Epoch 69 Batch 0 Loss 0.2636
# Epoch 69 Loss 0.2721
# Time taken for 1 epoch 0.8351962566375732 sec
#
# Epoch 70 Batch 0 Loss 0.2539
# Epoch 70 Loss 0.2599
# Time taken for 1 epoch 1.2401149272918701 sec
#
# Epoch 71 Batch 0 Loss 0.2376
# Epoch 71 Loss 0.2441
# Time taken for 1 epoch 0.8551933765411377 sec
#
# Epoch 72 Batch 0 Loss 0.2274
# Epoch 72 Loss 0.2304
# Time taken for 1 epoch 0.8441908359527588 sec
#
# Epoch 73 Batch 0 Loss 0.2078
# Epoch 73 Loss 0.2142
# Time taken for 1 epoch 0.8461906909942627 sec
#
# Epoch 74 Batch 0 Loss 0.1910
# Epoch 74 Loss 0.2017
# Time taken for 1 epoch 0.8627474308013916 sec
#
# Epoch 75 Batch 0 Loss 0.1784
# Epoch 75 Loss 0.1907
# Time taken for 1 epoch 1.2536959648132324 sec
#
# Epoch 76 Batch 0 Loss 0.1758
# Epoch 76 Loss 0.1794
# Time taken for 1 epoch 0.8631947040557861 sec
#
# Epoch 77 Batch 0 Loss 0.1552
# Epoch 77 Loss 0.1716
# Time taken for 1 epoch 0.8431901931762695 sec
#
# Epoch 78 Batch 0 Loss 0.1647
# Epoch 78 Loss 0.1616
# Time taken for 1 epoch 0.8381896018981934 sec
#
# Epoch 79 Batch 0 Loss 0.1393
# Epoch 79 Loss 0.1523
# Time taken for 1 epoch 0.8461916446685791 sec
#
# Epoch 80 Batch 0 Loss 0.1415
# Epoch 80 Loss 0.1485
# Time taken for 1 epoch 1.2771966457366943 sec
#
# Epoch 81 Batch 0 Loss 0.1287
# Epoch 81 Loss 0.1409
# Time taken for 1 epoch 0.8651947975158691 sec
#
# Epoch 82 Batch 0 Loss 0.1262
# Epoch 82 Loss 0.1346
# Time taken for 1 epoch 0.8501920700073242 sec
#
# Epoch 83 Batch 0 Loss 0.1179
# Epoch 83 Loss 0.1284
# Time taken for 1 epoch 0.8401899337768555 sec
#
# Epoch 84 Batch 0 Loss 0.1244
# Epoch 84 Loss 0.1196
# Time taken for 1 epoch 0.849191427230835 sec
#
# Epoch 85 Batch 0 Loss 0.1005
# Epoch 85 Loss 0.1119
# Time taken for 1 epoch 1.2616662979125977 sec
#
# Epoch 86 Batch 0 Loss 0.1056
# Epoch 86 Loss 0.1128
# Time taken for 1 epoch 0.8581938743591309 sec
#
# Epoch 87 Batch 0 Loss 0.0925
# Epoch 87 Loss 0.1083
# Time taken for 1 epoch 0.8541924953460693 sec
#
# Epoch 88 Batch 0 Loss 0.0923
# Epoch 88 Loss 0.0976
# Time taken for 1 epoch 0.8451910018920898 sec
#
# Epoch 89 Batch 0 Loss 0.0826
# Epoch 89 Loss 0.0885
# Time taken for 1 epoch 0.848191499710083 sec
#
# Epoch 90 Batch 0 Loss 0.0792
# Epoch 90 Loss 0.0803
# Time taken for 1 epoch 1.300694227218628 sec
#
# Epoch 91 Batch 0 Loss 0.0714
# Epoch 91 Loss 0.0740
# Time taken for 1 epoch 0.8391890525817871 sec
#
# Epoch 92 Batch 0 Loss 0.0644
# Epoch 92 Loss 0.0672
# Time taken for 1 epoch 0.8391895294189453 sec
#
# Epoch 93 Batch 0 Loss 0.0572
# Epoch 93 Loss 0.0609
# Time taken for 1 epoch 0.8471908569335938 sec
#
# Epoch 94 Batch 0 Loss 0.0500
# Epoch 94 Loss 0.0562
# Time taken for 1 epoch 0.8491923809051514 sec
#
# Epoch 95 Batch 0 Loss 0.0469
# Epoch 95 Loss 0.0496
# Time taken for 1 epoch 1.2653846740722656 sec
#
# Epoch 96 Batch 0 Loss 0.0422
# Epoch 96 Loss 0.0439
# Time taken for 1 epoch 0.8571934700012207 sec
#
# Epoch 97 Batch 0 Loss 0.0408
# Epoch 97 Loss 0.0402
# Time taken for 1 epoch 0.8451900482177734 sec
#
# Epoch 98 Batch 0 Loss 0.0353
# Epoch 98 Loss 0.0375
# Time taken for 1 epoch 0.8691966533660889 sec
#
# Epoch 99 Batch 0 Loss 0.0327
# Epoch 99 Loss 0.0337
# Time taken for 1 epoch 0.8511919975280762 sec
#
# Epoch 100 Batch 0 Loss 0.0273
# Epoch 100 Loss 0.0312
# Time taken for 1 epoch 1.298861026763916 sec

# %% [markdown]
# Evaluation (Translation)

# %%
def evaluate(sentence):
    """Translate a sentence
    Args:
        sentence: the test sentence        
    """
    
    # max_length_targ 38, max_length_inp 64
    attention_plot = np.zeros((max_length_targ, max_length_inp))

    sentence = preprocess(sentence)

    # convert each word to the index in the test sentence
    inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                           maxlen=max_length_inp,
                                                           padding='post')

    inputs = tf.convert_to_tensor(inputs)

    result = ''

    # hidden shape == (1, 1024)
    hidden = [tf.zeros((1, units))]
    
    # enc out shape == (1, max_length_inp, 1024) -> (1, 18, 1024)
    # enc hidden shape == (1, 1024)
    enc_out, enc_hidden = encoder(inputs, hidden)

    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

    for t in range(max_length_targ):
        predictions, dec_hidden, attention_weights = decoder(dec_input, dec_hidden, enc_out)
        
        # storing the attention weigths to plot later on
        attention_weights = tf.reshape(attention_weights, (-1, ))
        attention_plot[t] = attention_weights.numpy()

        # get the index which has the highest probability
        predicted_id = tf.argmax(predictions[0]).numpy()
        #  convert the index to the word
        result += targ_lang.index_word[predicted_id] + ' '

        # when the decoder predicts the end, stop prediction
        if targ_lang.index_word[predicted_id] == '<end>':
            return result, sentence, attention_plot

        # the predicted id is fed back into the model
        dec_input = tf.expand_dims([predicted_id], 0)

    return result, sentence, attention_plot


def translate(sentence):
    result, sentence, attention_plot= evaluate(sentence)
    return result.rpartition('<end>')[0].strip()

# %% [markdown]
# Restore the latest checkpoint and translate test set

# %%
checkpoint_dir = './checkpoints/tcn-eng'
print(tf.train.latest_checkpoint(checkpoint_dir))

# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))
# Out:
# ./checkpoints/tcn-eng\ckpt-20

# %%
test_set = pd.read_csv('./preprocessed/cleaned_test_tcn.csv').drop('split', axis=1)

# %%
test_set
# Out:
#                                          text   product_title_clean  \
# 0               【PolarStar】美麗諾羊毛保暖襪『淺灰』P18634            美麗諾羊毛保暖襪淺灰
# 1                        甜蜜水晶~天然水晶五行珠手鍊10mm手鍊       甜蜜水晶天然水晶五行珠手鍊手鍊
# 2                                   粉晶六角柱純銀項鍊             粉晶六角柱純銀項鍊
# 3             3M SCOTCH VHB 超強力雙面膠-戶外專用 V1808            超強力雙面膠戶外專用
# 4                                   燈專屬優惠 *4盒                燈專屬優惠盒
# ...                                       ...                   ...
# 9995       RAINS BACKPACK 後背包 公事包 筆電包 丹麥品牌 白色       後背包公事包筆電包丹麥品牌白色
# 9996    Airwalk 凉鞋 童鞋 深蓝色 中童 A823230180 no002             凉鞋童鞋深蓝色中童
# 9997  NORNS 【迪士尼5000mAh行動電源(泰瑞鴨)】迪士尼 鴨嘴獸泰瑞 充電  迪士尼行動電源泰瑞鴨迪士尼鴨嘴獸泰瑞充電
# 9998  DERWENT 達爾文設計製圖鉛筆 鐵盒12支(6B-4H),設計*34214        達爾文設計製圖鉛筆鐵盒支設計
# 9999                   Borofone BE11 運動磁吸藍芽耳機              運動磁吸藍芽耳機
#
#             product_title_processed
# 0                    美麗諾 羊毛 保暖 襪淺 灰
# 1           甜蜜 水晶 天然 水晶 五行 珠手 鍊 手 鍊
# 2                     粉晶 六角 柱純 銀項 鍊
# 3                    超強力 雙面 膠戶 外 專用
# 4                          燈 專屬 優惠盒
# ...                             ...
# 9995          後 背包 公事包 筆電 包丹麥 品牌 白色
# 9996                   凉鞋 童鞋 深蓝色 中童
# 9997  迪士尼 行動 電源 泰瑞 鴨 迪士尼 鴨 嘴獸 泰瑞 充電
# 9998       達爾文設 計 製 圖 鉛 筆 鐵 盒 支 設 計
# 9999                    運動 磁吸 藍芽 耳機
#
# [10000 rows x 3 columns]

# %%
test_tr_sents_all = []
for i in range(len(test_set['product_title_processed'])):
    try: test_tr_sents_all.append(translate(test_set['product_title_processed'][i]))
    except: test_tr_sents_all.append(np.nan)

# %%
test_tr_sents_all
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'temperament fresh practical hair band hair accessories hair hoop',
#  nan,
#  nan,
#  nan,
#  nan,
#  'apollo safe iron cabinet gold treasury library wealth lucky essential original warranty',
#  nan,
#  'gap classic logo patch top',
#  nan,
#  nan,
#  nan,
#  nan,
#  'coach horse carriage logo long wallet',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'jack wolfskin inflatable neck pillow',
#  nan,
#  nan,
#  nan,
#  'temperament fresh practical hair band hair accessories hair hoop',
#  nan,
#  nan,
#  nan,
#  'klorane star the hair gift set',
#  nan,
#  nan,
#  nan,
#  'ifairies large size long',
#  '',
#  nan,
#  nan,
#  nan,
#  'creative plus mobile phone lanyard all fall',
#  'adidas originals superstar w white embroidered floral casual shoes',
#  'polo shirt classic embroidery polo shirt custom fit',
#  nan,
#  nan,
#  'phyto hair flower plant shampoo paris d',
#  nan,
#  'royal sterilization greedy cat',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'handheld telescopic focusing led flashlight with holder',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'nike women wmns nike air zoom pegasus running shoes',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'nekopara vol mobile phone shell htc u ultra u play pro lifestyle',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'sea of spa dead sea exfoliating cream',
#  nan,
#  nan,
#  'adidas run sho m pack',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'adidas wild burst silicone watch black shoes',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'temperament fresh practical hair band hair accessories hair hoop',
#  nan,
#  nan,
#  'alviero martini map pack women choker circle triangle zircon earrings',
#  nan,
#  'korea tassel candy color straw thick bag three health dietary fiber',
#  'make up ever tote bag',
#  'parker ingenuity element series elite purple pink white pen f',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'slippers soft q cushioning comfortable slippers elsa',
#  nan,
#  'breakout crisis dvd vol',
#  nan,
#  'estee lauder young cream',
#  nan,
#  nan,
#  nan,
#  'parker jotter series steel rod pen f',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'alviero martini map pack women choker circle triangle zircon earrings',
#  nan,
#  nan,
#  nan,
#  'new balance pink grey',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'apieu color lip pencil matt silk satin',
#  nan,
#  nan,
#  nan,
#  'the fresh adult diapers m pc',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'ready stock leaves in racks angle clip',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'moschino small pink fresh women edt',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'shiny glossy long edition perspective shirt',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'jack wolfskin inflatable neck pillow',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'infant soft along the magic baby',
#  nan,
#  nan,
#  'hollow totem embroidery shirt',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'marlmarl dolce dessert bib pink lace',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'at ink topmore stone dual usb car charger a',
#  nan,
#  'panties cotton cartoon triangle logo british tide outdoor fashion casual short sleeve t',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'adidas tf mcb mchth aerobic paint punch metal',
#  'gap classic logo patch top',
#  nan,
#  'fashion simple practical pillow cushion sofa decor pillow bolster',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'kgh fashion polarized sports sunglasses vie pbpl mola sports',
#  'thick bottom loose bottom travel shoes harajuku shoes',
#  'ifairies large size long',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'the trend of the shop palace triangle logo long sleeve hooded jacket',
#  'ifairies earrings',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'ifairies coin pack',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'parker jotter tablets series',
#  nan,
#  'medical grade manuka elixir of major cream',
#  nan,
#  nan,
#  nan,
#  nan,
#  'nike jordan flight runner basketball shoes men s big o sports',
#  nan,
#  nan,
#  'moonstar hiking shoes black shoes',
#  'cowboy curling jeans shorts',
#  'portable soap paper sheets x pc',
#  nan,
#  nan,
#  nan,
#  'new balance women s shoes',
#  nan,
#  nan,
#  nan,
#  nan,
#  'nike women wmns nike air zoom pegasus running shoes',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'klorane star the hair gift set',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'white coffee shop mellow cappuccino white gold bird essence',
#  nan,
#  nan,
#  'airpillow samsung note note full air cushion clear transparent back cover',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'nike w blazer low le classic retro shoes',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'watanabe health dietary fiber pack',
#  'nillkin sony xperia premium amazing h glass sticker back',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'karite paris shea rose queen moisturizing hand cream',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'nike jordan flight runner basketball shoes big o sports',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'three layer paint punch metal',
#  nan,
#  nan,
#  nan,
#  nan,
#  'jack wolfskin inflatable neck pillow',
#  nan,
#  nan,
#  'canmake just for you in color change lip gloss',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'gap classic logo long sleeve logo patch top',
#  nan,
#  nan,
#  nan,
#  'polarstar windproof warm coat',
#  'infant soft along the magic baby',
#  nan,
#  nan,
#  nan,
#  'innoshop new disney paradise princess bottle shape necklace',
#  nan,
#  nan,
#  nan,
#  nan,
#  'nike as w nk df knit tank sports pants male',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'cross virgin oval leather shoulder dslr pack diagonal outdoor fashion color lip pencil matt silk satin',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'jack wolfskin inflatable neck pillow',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'iphone punk rivet hair ball pendant black women',
#  nan,
#  'cloud story the vol',
#  nan,
#  nan,
#  nan,
#  nan,
#  'adidas d rose englewood iv td basketball shoes men',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'nike as lebron m nk therma pant casual sports shoes men big o sports',
#  nan,
#  nan,
#  nan,
#  'girls short sleeve home suit magic baby',
#  'nike air berwuda prm retro sports shoes male big o sports',
#  'jack wolfskin inflatable neck pillow',
#  nan,
#  nan,
#  nan,
#  'new balance white gold bird essence',
#  nan,
#  'old heather circle triangle zircon earrings',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'marlmarl dolce dessert bib pink lace',
#  nan,
#  nan,
#  nan,
#  nan,
#  'michael kors jet set scratch resistant leather phone clutch bag',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'tree de sc multifunctional locker',
#  nan,
#  nan,
#  'mizuno wave inspire men running shoes big o sports',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'nike women wmns nike air zoom pegasus running shoes',
#  'adidas superatar bold w leather gold ballpoint pen',
#  nan,
#  nan,
#  nan,
#  nan,
#  'kgh backpack korean backpack tablet backpack casual messenger pack korean cycling pack oblique backpack',
#  'korea welfare bbia golden rose gold ball pen',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'mr bubble phone case sony x xa ultra xzs xz xzp compact',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'at ink topmore stone dual usb car charger a',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'japan azzeen planting queen lotion',
#  'slippers magic slippers with',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'toro good plant door wardrobe',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'baby boy student sweater warm ladies wind a',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'ifairies shoulder messenger bag shoulder bag',
#  nan,
#  'japan holbein heavy body colors acrylic paint',
#  nan,
#  'kiro cat love cat waterproof anti slip invisible socks',
#  nan,
#  nan,
#  'new balance women jogging shoes',
#  nan,
#  nan,
#  'the spring spa tencel classic white pen ef f m',
#  nan,
#  nan,
#  nan,
#  nan,
#  '',
#  nan,
#  nan,
#  nan,
#  nan,
#  'with incense jujube pack pc pack',
#  nan,
#  'basecamp dustproof windproof mask',
#  nan,
#  nan,
#  nan,
#  'bubble airbag cushion phone shell transparent shell',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'the soothing dry itching cream',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'adidas d rose englewood iv td basketball shoes men',
#  nan,
#  'goospery apple iphone plus pudding case soft cover',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'nekopara phone case for asus zenfone deluxe ultra zoom laser selfie go',
#  nan,
#  nan,
#  nan,
#  nan,
#  'double zipper pocket solid waterproof anti theft backpack',
#  nan,
#  nan,
#  'poli bonny rescue hero robocar sandals blue cases',
#  nan,
#  'hario black',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'baby shoes infant anti slip prewalker magic baby',
#  nan,
#  nan,
#  nan,
#  'medical grade manuka elixir of major cream',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'make up ever tote bag',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'nike jordan flight runner basketball shoes big o sports',
#  nan,
#  'cotton printed pocket lunch bag',
#  nan,
#  nan,
#  nan,
#  'japan soup small clay pot casserole a',
#  nan,
#  nan,
#  nan,
#  'coach floral splicing handbag crossbody boston pack',
#  nan,
#  nan,
#  nan,
#  'ifairies shoulder messenger bag shoulder bag',
#  nan,
#  nan,
#  'hater snapback velvet cap flannel snapback black',
#  nan,
#  nan,
#  nan,
#  'karl lagerfeld fever theme cat hat black',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'tops casual multi color polo shirt elsa',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'ifairies large size dress',
#  nan,
#  nan,
#  nan,
#  'tops female',
#  nan,
#  'nike wmns nike lunarglide jogging shoes female big o sportsnike',
#  nan,
#  nan,
#  'peripera _ milk color lip balm',
#  nan,
#  'kimo outdoor casual shoes black shoes',
#  nan,
#  nan,
#  nan,
#  nan,
#  'polo shirt classic plain leather flip long sleeve princess bottle',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'at ink topmore stone dual usb car charger a',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'ifairies large size dress',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'ifairies large size dress',
#  'germany jansen handmade ink wine bottle',
#  nan,
#  'new balance women jogging suede mesh computer bag',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'slippers soft q cushioning comfortable slippers elsa',
#  nan,
#  nan,
#  nan,
#  'men s shoes',
#  nan,
#  'adidas run sho m sport jogging shorts big o sports',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'htc phone shell htc u ultra u play pro lifestyle',
#  nan,
#  'yu germany computer printing label grid pcs pack',
#  'perfect cut maple leaf loveteam letter casual short t',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'new balance women jogging suede mesh black shoes',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'mercury denim pattern cover',
#  nan,
#  nan,
#  'ifairies coin pack',
#  nan,
#  nan,
#  'love cat snack pc hybrid',
#  nan,
#  'nike as lebron m nk therma pant casual sports vest jogging shorts big o sports',
#  nan,
#  'sexy side cardigan two type sleep shirt powder sweet heart',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'roush stand collar open button design brush cap teee',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'side backpack oblique backpack',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'baby shoes infant anti slip prewalker magic baby',
#  'cotton printed pocket lunch bag',
#  nan,
#  nan,
#  nan,
#  ...]

# %%
test_set['prediction'] = test_tr_sents_all

# %%
test_set
# Out:
#                                          text   product_title_clean  \
# 0               【PolarStar】美麗諾羊毛保暖襪『淺灰』P18634            美麗諾羊毛保暖襪淺灰
# 1                        甜蜜水晶~天然水晶五行珠手鍊10mm手鍊       甜蜜水晶天然水晶五行珠手鍊手鍊
# 2                                   粉晶六角柱純銀項鍊             粉晶六角柱純銀項鍊
# 3             3M SCOTCH VHB 超強力雙面膠-戶外專用 V1808            超強力雙面膠戶外專用
# 4                                   燈專屬優惠 *4盒                燈專屬優惠盒
# ...                                       ...                   ...
# 9995       RAINS BACKPACK 後背包 公事包 筆電包 丹麥品牌 白色       後背包公事包筆電包丹麥品牌白色
# 9996    Airwalk 凉鞋 童鞋 深蓝色 中童 A823230180 no002             凉鞋童鞋深蓝色中童
# 9997  NORNS 【迪士尼5000mAh行動電源(泰瑞鴨)】迪士尼 鴨嘴獸泰瑞 充電  迪士尼行動電源泰瑞鴨迪士尼鴨嘴獸泰瑞充電
# 9998  DERWENT 達爾文設計製圖鉛筆 鐵盒12支(6B-4H),設計*34214        達爾文設計製圖鉛筆鐵盒支設計
# 9999                   Borofone BE11 運動磁吸藍芽耳機              運動磁吸藍芽耳機
#
#             product_title_processed                   prediction
# 0                    美麗諾 羊毛 保暖 襪淺 灰                          NaN
# 1           甜蜜 水晶 天然 水晶 五行 珠手 鍊 手 鍊                          NaN
# 2                     粉晶 六角 柱純 銀項 鍊                          NaN
# 3                    超強力 雙面 膠戶 外 專用                          NaN
# 4                          燈 專屬 優惠盒                          NaN
# ...                             ...                          ...
# 9995          後 背包 公事包 筆電 包丹麥 品牌 白色                          NaN
# 9996                   凉鞋 童鞋 深蓝色 中童                          NaN
# 9997  迪士尼 行動 電源 泰瑞 鴨 迪士尼 鴨 嘴獸 泰瑞 充電                          NaN
# 9998       達爾文設 計 製 圖 鉛 筆 鐵 盒 支 設 計                          NaN
# 9999                    運動 磁吸 藍芽 耳機  cowboy curling jeans shorts
#
# [10000 rows x 4 columns]

# %%
test_set.isna().sum()
# Out:
# text                          0
# product_title_clean          72
# product_title_processed      72
# prediction                 8606
# dtype: int64

# %%
test_set.dropna(inplace=True)
test_set
# Out:
#                                                    text  \
# 14                                   時尚氣質清新實用髮帶 髮飾 髮箍94
# 19            阿波羅保險箱 保險櫃 鐵櫃 金庫 財庫 財神 招財必備 公司原廠保固 600ALD
# 21                                       國際牌 CR-1632/1B
# 26                 Abercrombie & Fitch A&F 經典logo刺繡連帽外套
# 38    GOR ASUS ZenFone 3 2 Deluxe Ultra Zoon Max Las...
# ...                                                 ...
# 9967  玉米潮流本舖 SUPREME arabic logo LS tee FW17T34 長TEE 灰色
# 9969                     時尚簡約實用抱枕14 靠墊 沙發裝飾靠枕 (45*30cm)
# 9971                                 SKB 迷你釘書機 【18-273】
# 9981                        iFairies 單肩斜背包側背包肩背包【55306】
# 9999                             Borofone BE11 運動磁吸藍芽耳機
#
#               product_title_clean                 product_title_processed  \
# 14                 時尚氣質清新實用髮帶髮飾髮箍                 時尚 氣質 清新 實用 髮 帶 髮 飾 髮 箍
# 19    阿波羅保險箱保險櫃鐵櫃金庫財庫財神招財必備公司原廠保固  阿波羅 保險箱 保險 櫃鐵櫃 金庫 財庫 財神 招財 必備 公司 原廠 保固
# 21                            國際牌                                     國際牌
# 26                       經典刺繡連帽外套                            經典 刺 繡 連帽 外套
# 38                          玻璃保護貼                                 玻璃 保護 貼
# ...                           ...                                     ...
# 9967                    玉米潮流本舖長灰色                          玉米 潮流 本 舖 長 灰色
# 9969             時尚簡約實用抱枕靠墊沙發裝飾靠枕               時尚 簡約 實用 抱 枕 靠 墊 沙發 裝飾 靠枕
# 9971                        迷你釘書機                                  迷你 釘書機
# 9981                  單肩斜背包側背包肩背包                       單肩 斜 背包 側 背包 肩 背包
# 9999                     運動磁吸藍芽耳機                             運動 磁吸 藍芽 耳機
#
#                                              prediction
# 14    temperament fresh practical hair band hair acc...
# 19    apollo safe iron cabinet gold treasury library...
# 21                           gap classic logo patch top
# 26                coach horse carriage logo long wallet
# 38                 jack wolfskin inflatable neck pillow
# ...                                                 ...
# 9967    cross virgin oval leather shoulder black coffee
# 9969  fashion simple practical pillow cushion sofa d...
# 9971            ancko usa anti uv candy ice t men black
# 9981       ifairies shoulder messenger bag shoulder bag
# 9999                        cowboy curling jeans shorts
#
# [1394 rows x 4 columns]

# %%
test_set.to_csv('./output/1_NMT_test_output1.csv', index=False, encoding='utf_8_sig')

# %% [markdown]
# Translate DEV set for BLEU Score Evaluation

# %%
tcn_clean
# Out:
#                                                   text    split  \
# 0                  OPPO A75 A75s A73 手机壳 软壳 挂绳壳 大眼兔硅胶壳  private
# 1                                  SOFT 99 鍍膜車蠟(強力撥水型)  private
# 2                                       低糖芒果乾 250g 臻御行  private
# 3    ＊小徑文化＊日本進口ROUND TOP space craft - diamond (SC-...  private
# 4            Hello Kitty 凱蒂貓 KITTY 涼鞋 童鞋 白/紅色 小童 no739  private
# ..                                                 ...      ...
# 995                【HippoRed】撕破乐趣★独特风格★中直筒牛仔裤 O591_445  private
# 996                      兒童套裝 台灣製薄長袖居家套裝 魔法Baby~k60092  private
# 997                 LONGCHAMP Le Pliage Neo高密尼龍後背包(中型)  private
# 998            iFairies 開口可調節戒指★ifairies【56472】【56472】  private
# 999                        PolarStar 女 排汗快干T恤『黑』P18102  private
#
#     product_title_clean     product_title_processed
# 0        手机壳软壳挂绳壳大眼兔硅胶壳      手机 壳 软壳 挂绳 壳 大眼 兔 硅胶 壳
# 1             鍍膜車蠟強力撥水型                鍍膜車 蠟 強力 撥水型
# 2              低糖芒果乾臻御行                 低糖 芒果乾 臻 御行
# 3              小徑文化日本進口                 小徑 文化 日本 進口
# 4          凱蒂貓涼鞋童鞋白紅色小童            凱蒂貓 涼鞋 童鞋 白紅色 小童
# ..                  ...                         ...
# 995      撕破乐趣独特风格中直筒牛仔裤        撕破 乐趣 独特 风格 中直 筒 牛仔裤
# 996    兒童套裝台灣製薄長袖居家套裝魔法  兒童 套 裝台 灣 製 薄 長 袖 居家 套裝 魔法
# 997           高密尼龍後背包中型               高密 尼龍 後 背包 中型
# 998             開口可調節戒指                  開口 可 調節 戒指
# 999             女排汗快干恤黑                 女排 汗 快干 恤 黑
#
# [1000 rows x 4 columns]

# %%
dev_tr_sents_all = []
for i in range(len(tcn_clean['product_title_processed'])):
    try: dev_tr_sents_all.append(translate(tcn_clean['product_title_processed'][i]))
    except: dev_tr_sents_all.append(np.nan)

# %%
tcn_clean['prediction']= dev_tr_sents_all

# %%
tcn_clean.drop('split', axis=1, inplace = True)
tcn_clean
# Out:
#                                                   text product_title_clean  \
# 0                  OPPO A75 A75s A73 手机壳 软壳 挂绳壳 大眼兔硅胶壳      手机壳软壳挂绳壳大眼兔硅胶壳
# 1                                  SOFT 99 鍍膜車蠟(強力撥水型)           鍍膜車蠟強力撥水型
# 2                                       低糖芒果乾 250g 臻御行            低糖芒果乾臻御行
# 3    ＊小徑文化＊日本進口ROUND TOP space craft - diamond (SC-...            小徑文化日本進口
# 4            Hello Kitty 凱蒂貓 KITTY 涼鞋 童鞋 白/紅色 小童 no739        凱蒂貓涼鞋童鞋白紅色小童
# ..                                                 ...                 ...
# 995                【HippoRed】撕破乐趣★独特风格★中直筒牛仔裤 O591_445      撕破乐趣独特风格中直筒牛仔裤
# 996                      兒童套裝 台灣製薄長袖居家套裝 魔法Baby~k60092    兒童套裝台灣製薄長袖居家套裝魔法
# 997                 LONGCHAMP Le Pliage Neo高密尼龍後背包(中型)           高密尼龍後背包中型
# 998            iFairies 開口可調節戒指★ifairies【56472】【56472】             開口可調節戒指
# 999                        PolarStar 女 排汗快干T恤『黑』P18102             女排汗快干恤黑
#
#         product_title_processed  \
# 0        手机 壳 软壳 挂绳 壳 大眼 兔 硅胶 壳
# 1                  鍍膜車 蠟 強力 撥水型
# 2                   低糖 芒果乾 臻 御行
# 3                   小徑 文化 日本 進口
# 4              凱蒂貓 涼鞋 童鞋 白紅色 小童
# ..                          ...
# 995        撕破 乐趣 独特 风格 中直 筒 牛仔裤
# 996  兒童 套 裝台 灣 製 薄 長 袖 居家 套裝 魔法
# 997               高密 尼龍 後 背包 中型
# 998                  開口 可 調節 戒指
# 999                 女排 汗 快干 恤 黑
#
#                                             prediction
# 0            oppo phone case soft rabbit silicone case
# 1               soft coating car wax strong water watt
# 2                     low sugar mango dry be the royal
# 3    the culture japan imported round top space cra...
# 4         hello kitty sandals shoes white red children
# ..                                                 ...
# 995      hippored torn fun unique style straight jeans
# 996  kids set table bay thin long sleeve home suit ...
# 997  longchamp le pliage neo high density nylon bac...
# 998                 watanabe health dietary fiber pack
# 999                         big v collar chiffon shirt
#
# [1000 rows x 4 columns]

# %%
tcn_clean['prediction'] = tcn_clean['prediction'].replace(r'^\s*$', np.NaN, regex=True) #removes empty strings or strings containing only spaces with NaN

# %%
tcn_clean.isna().sum()
# Out:
# text                        0
# product_title_clean         6
# product_title_processed     6
# prediction                 14
# dtype: int64

# %%
tcn_clean.loc[pd.isna(tcn_clean).any(1), :].index #check nan after translated rows indexes
# Out:
# Int64Index([148, 218, 260, 306, 373, 396, 505, 568, 593, 597, 626, 717, 853,
#             881],
#            dtype='int64')

# %%
tr_nan_indexes = tcn_clean.loc[pd.isna(tcn_clean).any(1), :].index #stores nan indexes for later dev_en follow to drop nan rows as well
tr_nan_indexes
# Out:
# Int64Index([148, 218, 260, 306, 373, 396, 505, 568, 593, 597, 626, 717, 853,
#             881],
#            dtype='int64')

# %%
tcn_clean = tcn_clean.dropna()
tcn_clean.isna().sum()
# Out:
# text                       0
# product_title_clean        0
# product_title_processed    0
# prediction                 0
# dtype: int64

# %%
tcn_clean.to_csv('./output/1_NMT_dev_output1.csv',index = False, encoding='utf_8_sig')

# %%
dev_tr_sents_all_df = pd.read_csv('./output/1_NMT_dev_output1.csv')

# %%
dev_tr_sents_all_df
# Out:
#                                                   text product_title_clean  \
# 0                  OPPO A75 A75s A73 手机壳 软壳 挂绳壳 大眼兔硅胶壳      手机壳软壳挂绳壳大眼兔硅胶壳
# 1                                  SOFT 99 鍍膜車蠟(強力撥水型)           鍍膜車蠟強力撥水型
# 2                                       低糖芒果乾 250g 臻御行            低糖芒果乾臻御行
# 3    ＊小徑文化＊日本進口ROUND TOP space craft - diamond (SC-...            小徑文化日本進口
# 4            Hello Kitty 凱蒂貓 KITTY 涼鞋 童鞋 白/紅色 小童 no739        凱蒂貓涼鞋童鞋白紅色小童
# ..                                                 ...                 ...
# 981                【HippoRed】撕破乐趣★独特风格★中直筒牛仔裤 O591_445      撕破乐趣独特风格中直筒牛仔裤
# 982                      兒童套裝 台灣製薄長袖居家套裝 魔法Baby~k60092    兒童套裝台灣製薄長袖居家套裝魔法
# 983                 LONGCHAMP Le Pliage Neo高密尼龍後背包(中型)           高密尼龍後背包中型
# 984            iFairies 開口可調節戒指★ifairies【56472】【56472】             開口可調節戒指
# 985                        PolarStar 女 排汗快干T恤『黑』P18102             女排汗快干恤黑
#
#         product_title_processed  \
# 0        手机 壳 软壳 挂绳 壳 大眼 兔 硅胶 壳
# 1                  鍍膜車 蠟 強力 撥水型
# 2                   低糖 芒果乾 臻 御行
# 3                   小徑 文化 日本 進口
# 4              凱蒂貓 涼鞋 童鞋 白紅色 小童
# ..                          ...
# 981        撕破 乐趣 独特 风格 中直 筒 牛仔裤
# 982  兒童 套 裝台 灣 製 薄 長 袖 居家 套裝 魔法
# 983               高密 尼龍 後 背包 中型
# 984                  開口 可 調節 戒指
# 985                 女排 汗 快干 恤 黑
#
#                                             prediction
# 0            oppo phone case soft rabbit silicone case
# 1               soft coating car wax strong water watt
# 2                     low sugar mango dry be the royal
# 3    the culture japan imported round top space cra...
# 4         hello kitty sandals shoes white red children
# ..                                                 ...
# 981      hippored torn fun unique style straight jeans
# 982  kids set table bay thin long sleeve home suit ...
# 983  longchamp le pliage neo high density nylon bac...
# 984                 watanabe health dietary fiber pack
# 985                         big v collar chiffon shirt
#
# [986 rows x 4 columns]

# %%
# !pip install sacrebleu
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting sacrebleu
#   Downloading sacrebleu-1.5.1-py3-none-any.whl (54 kB)
# Collecting portalocker==2.0.0
#   Downloading portalocker-2.0.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: pywin32!=226 in c:\users\yeele\miniconda3\lib\site-packages (from portalocker==2.0.0->sacrebleu) (227)
# Installing collected packages: portalocker, sacrebleu
# Successfully installed portalocker-2.0.0 sacrebleu-1.5.1

# %%
import sacrebleu

# %%
dev_en_sents = en_clean.drop(tr_nan_indexes) # dropping same set of indexes as dev_tr for bleu scorer to match

# %%
refs = [dev_en_sents['translation_output']]
sys = dev_tr_sents_all_df['prediction']
bleu = sacrebleu.corpus_bleu(sys, refs, lowercase=True)
print(bleu.precisions)
# Out:
# [95.30453447813255, 95.06802721088435, 94.98358263407515, 94.89115948467348]
