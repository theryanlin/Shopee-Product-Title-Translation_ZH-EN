# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import unicodedata
import re
import numpy as np
import os
import time
import pandas as pd
from sklearn.model_selection import train_test_split

from pylab import *
from matplotlib.font_manager import FontProperties
print('tf.__version__.is', tf.__version__)
print('tf.keras.__version__ is:', tf.keras.__version__)
print(tf.config.experimental.list_physical_devices('GPU'))
# Out:
# tf.__version__.is 2.5.0
# tf.keras.__version__ is: 2.5.0
# []

# %% [markdown]
# Dataset loading

# %%
tcn_clean = pd.read_csv('./preprocessed/cleaned_dev_tcn.csv')
tcn_clean.head()
# Out:
#                                                 text    split  \
# 0                OPPO A75 A75s A73 手机壳 软壳 挂绳壳 大眼兔硅胶壳  private
# 1                                SOFT 99 鍍膜車蠟(強力撥水型)  private
# 2                                     低糖芒果乾 250g 臻御行  private
# 3  ＊小徑文化＊日本進口ROUND TOP space craft - diamond (SC-...  private
# 4          Hello Kitty 凱蒂貓 KITTY 涼鞋 童鞋 白/紅色 小童 no739  private
#
#   product_title_clean product_title_processed
# 0      手机壳软壳挂绳壳大眼兔硅胶壳  手机 壳 软壳 挂绳 壳 大眼 兔 硅胶 壳
# 1           鍍膜車蠟強力撥水型            鍍膜車 蠟 強力 撥水型
# 2            低糖芒果乾臻御行             低糖 芒果乾 臻 御行
# 3            小徑文化日本進口             小徑 文化 日本 進口
# 4        凱蒂貓涼鞋童鞋白紅色小童        凱蒂貓 涼鞋 童鞋 白紅色 小童

# %%
en_clean = pd.read_csv('./preprocessed/cleaned_dev_en.csv')
en_clean.head()
# Out:
#                                   translation_output
# 0          oppo phone case soft rabbit silicone case
# 1             soft coating car wax strong water watt
# 2                   low sugar mango dry be the royal
# 3  the culture japan imported round top space cra...
# 4       hello kitty sandals shoes white red children

# %% [markdown]
# Preprocessing (change from unicode to ascii & add \<start\> and \<end\> tokens

# %%
def unicode_to_ascii(s):
    return ''.join(c for c in unicodedata.normalize('NFD', s)
                   if unicodedata.category(c) != 'Mn')

# %%
def preprocess(w):
    w = unicode_to_ascii(w.lower().strip())

    # adding a start and an end token to the sentence
    # so that the model know when to start and stop predicting.
    w = '<start> ' + w + ' <end>'
    return w

# %%
# u means unicode encoder
en_sentence = en_clean['translation_output'][0]
chn_sentence = tcn_clean['product_title_processed'][0]
print(preprocess(en_sentence))
print(preprocess(chn_sentence))
print(preprocess(chn_sentence).encode('utf-8'))
# Out:
# <start> oppo phone case soft rabbit silicone case <end>
# <start> 手机 壳 软壳 挂绳 壳 大眼 兔 硅胶 壳 <end>
# b'<start> \xe6\x89\x8b\xe6\x9c\xba \xe5\xa3\xb3 \xe8\xbd\xaf\xe5\xa3\xb3 \xe6\x8c\x82\xe7\xbb\xb3 \xe5\xa3\xb3 \xe5\xa4\xa7\xe7\x9c\xbc \xe5\x85\x94 \xe7\xa1\x85\xe8\x83\xb6 \xe5\xa3\xb3 <end>'

# %% [markdown]
# Prepare Embedding Layer

# %%
def create_dataset(target, source):
    assert len(source) == len(target)
    word_pairs = [[preprocess(str(target[i])), preprocess(str(source[i]))]
                  for i in range(len(source))]

    # return two tuple: one tuple includes all English sentenses, and 
    # another tuple includes all Chinese sentenses
    return word_pairs

word_pairs = create_dataset(en_clean['translation_output'], tcn_clean['product_title_processed'])
word_pairs[:20]
# Out:
# [['<start> oppo phone case soft rabbit silicone case <end>',
#   '<start> 手机 壳 软壳 挂绳 壳 大眼 兔 硅胶 壳 <end>'],
#  ['<start> soft coating car wax strong water watt <end>',
#   '<start> 鍍膜車 蠟 強力 撥水型 <end>'],
#  ['<start> low sugar mango dry be the royal <end>',
#   '<start> 低糖 芒果乾 臻 御行 <end>'],
#  ['<start> the culture japan imported round top space craft diamond sc mk <end>',
#   '<start> 小徑 文化 日本 進口 <end>'],
#  ['<start> hello kitty sandals shoes white red children <end>',
#   '<start> 凱蒂貓 涼鞋 童鞋 白紅色 小童 <end>'],
#  ['<start> thunderbird lt japanese wood grain table mat x cm pc <end>',
#   '<start> 雷鳥 日式 木紋 桌墊片 <end>'],
#  ['<start> the sand kid dvd vol <end>', '<start> 狂砂 小子 <end>'],
#  ['<start> anacomda python titan series ssd drive <end>',
#   '<start> 巨蟒 泰坦 系列 固態 硬碟 <end>'],
#  ['<start> ifairies shoulder messenger bag shoulder bag <end>',
#   '<start> 單肩 斜 背包 側 背包 肩 背包 <end>'],
#  ['<start> the farm mountain bitter gourd tea pack box <end>',
#   '<start> 大雪山 農場 山 苦瓜 茶 包盒 <end>'],
#  ['<start> colgate dual clean toothbrush <end>',
#   '<start> 高露潔 雙效潔淨 牙刷 單支 <end>'],
#  ['<start> apieu color lip pencil matt silk satin <end>', '<start> 絲緞 <end>'],
#  ['<start> reese s away milan rose gold ball pen <end>',
#   '<start> 芮菲 客米蘭 玫瑰 金鋼 珠筆 <end>'],
#  ['<start> finding nemo glass magnet dolly _ the beast <end>',
#   '<start> 海底 總動員 玻璃 磁鐵多莉款 野獸國 <end>'],
#  ['<start> natural licorice oval pumpkin seeds <end>',
#   '<start> 甘草 瓜子 南瓜子 <end>'],
#  ['<start> papago hd driving recorder <end>', '<start> 行車 記錄器 <end>'],
#  ['<start> ista izmir the mesh head <end>', '<start> 伊士 達 分濾 網頭 <end>'],
#  ['<start> dot focus adidas essentials chest logo square box gray blue hooded men <end>',
#   '<start> 聚點 方形 方塊 灰 藍連帽 帽 男款 <end>'],
#  ['<start> tassel solid thread moka one blue black <end>',
#   '<start> 流蘇立體 縫線 莫卡 辛鞋 藍 黑色 <end>'],
#  ['<start> new fashion cute baby embroidery dress <end>',
#   '<start> 新品 時 尚可 愛寶寶繡 花連 衣裙 洋裝 <end>']]

# %%
en, chn = zip(*create_dataset(en_clean['translation_output'], tcn_clean['product_title_processed']))
print(en[-1])
print(chn[-1])
# show the size of the dataset
assert len(en) == len(chn)
print("Size:", len(en))
# Out:
# <start> polarstar women sweat quick dry t shirt black <end>
# <start> 女排 汗 快干 恤 黑 <end>
# Size: 1000

# %%
def tokenize(lang):
    lang_tokenizer = tf.keras.preprocessing.text.Tokenizer(
        filters='')
    # generate a dictionary, e.g. word -> index(of the dictionary)
    lang_tokenizer.fit_on_texts(lang)

    # output the vector sequences, e.g. [1, 7, 237, 3, 2]
    tensor = lang_tokenizer.texts_to_sequences(lang)

    # padding sentences to the same length
    tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,
                                                           padding='post')
    return tensor, lang_tokenizer

# %%
def load_dataset(target, source):
    # creating cleaned input, output pairs
    # regard Chinese as source sentence, regard English as target sentence
    targ_lang, inp_lang = zip(*create_dataset(target, source))

    input_tensor, inp_lang_tokenizer = tokenize(inp_lang)
    target_tensor, targ_lang_tokenizer = tokenize(targ_lang)

    return input_tensor, target_tensor, inp_lang_tokenizer, targ_lang_tokenizer

# %%
def max_length(tensor):
    # padding the sentence to max_length
    return max(len(t) for t in tensor)

# %%
input_tensor, target_tensor, inp_lang, targ_lang = load_dataset(en_clean['translation_output'], 
                                                                tcn_clean['product_title_processed'])

# Calculate max_length of the target tensors
max_length_targ, max_length_inp = max_length(
    target_tensor), max_length(input_tensor)

# Creating training and validation sets using an 95-5 split
input_tensor_train, input_tensor_val, target_tensor_train, target_tensor_val = train_test_split(
    input_tensor, target_tensor, test_size=0.05)

# Show length of the training data and validation data
print("# training data: {:d}\n# test data: {:d}".format(len(input_tensor_train), len(input_tensor_val)))
# Out:
# # training data: 950
# # test data: 50

# %%
def convert(lang, tensor):
    for t in tensor:
        if t != 0:
            print("%d ----> %s" % (t, lang.index_word[t]))

print("Input Language; index to word mapping")
convert(inp_lang, input_tensor_train[0])
print()
print("Target Language; index to word mapping")
convert(targ_lang, target_tensor_train[0])
# Out:
# Input Language; index to word mapping
# 1 ----> <start>
# 277 ----> 凱蒂貓
# 112 ----> 涼鞋
# 152 ----> 童鞋
# 849 ----> 白紅色
# 278 ----> 小童
# 2 ----> <end>
#
# Target Language; index to word mapping
# 1 ----> <start>
# 181 ----> hello
# 150 ----> kitty
# 182 ----> sandals
# 3 ----> shoes
# 13 ----> white
# 76 ----> red
# 207 ----> children
# 2 ----> <end>

# %% [markdown]
# Initialise Parameters

# %%
BUFFER_SIZE = len(input_tensor_train)
BATCH_SIZE = 128
steps_per_epoch = len(input_tensor_train)//BATCH_SIZE
embedding_dim = 256
units = 1024
# 0 is a reserved index that won't be assigned to any word, so the size of vocabulary should add 1
vocab_inp_size = len(inp_lang.word_index) + 1
vocab_tar_size = len(targ_lang.word_index) + 1

dataset = tf.data.Dataset.from_tensor_slices(
    (input_tensor_train, target_tensor_train)).shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)

example_input_batch, example_target_batch = next(iter(dataset))
example_input_batch.shape, example_target_batch.shape
# Out:
# 2025-03-11 17:00:34.020954: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (TensorShape([128, 18]), TensorShape([128, 17]))

# %%
print('vocab_inp_size =', vocab_inp_size)
print('vocab_tar_size =', vocab_tar_size)
# Out:
# vocab_inp_size = 3224
# vocab_tar_size = 2494

# %% [markdown]
# Encoder class construction

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, enc_units, batch_sz):
        # vacab_size=vocab_inp_size=3224, embedding_dim=256 enc_units=1024 batch_sz=128
        super(Encoder, self).__init__()
        self.batch_sz = batch_sz
        self.enc_units = enc_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.enc_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_activation='sigmoid',
                                       recurrent_initializer='glorot_uniform')

    def call(self, x, hidden):
        # x is the training data with shape == (batch_size, max_length)  -> (128, 18)
        # which means there are batch_size sentences in one batch, the length of each sentence is max_length
        # hidden state shape == (batch_size, units) -> (128, 1024)
        # after embedding, x shape == (batch_size, max_length, embedding_dim) -> (128, 18, 256)
        x = self.embedding(x)
        
        # output contains the state(in GRU, the hidden state and the output are same) from all timestamps,
        # output shape == (batch_size, max_length, units) -> (128, 18, 1024)
        # state is the hidden state of the last timestamp, shape == (batch_size, units) -> (128, 1024)
        output, state = self.gru(x, initial_state=hidden)
        
        return output, state

    def initialize_hidden_state(self):
        # initialize the first state of the gru,  shape == (batch_size, units) -> (128, 1024)
        return tf.zeros((self.batch_sz, self.enc_units))

# %%
encoder = Encoder(vocab_inp_size, embedding_dim, units, BATCH_SIZE)

# sample input
sample_hidden = encoder.initialize_hidden_state()
sample_output, sample_hidden = encoder(example_input_batch, sample_hidden)
print('Encoder output shape: (batch size, sequence length, units) {}'.format(sample_output.shape))
print('Encoder Hidden state shape: (batch size, units) {}'.format(sample_hidden.shape))

# the output and the hidden state of GRU is equal
print(sample_output[-1, -1, :] == sample_hidden[-1, :])
# Out:
# Encoder output shape: (batch size, sequence length, units) (128, 18, 1024)
# Encoder Hidden state shape: (batch size, units) (128, 1024)
# tf.Tensor([ True  True  True ...  True  True  True], shape=(1024,), dtype=bool)

# %% [markdown]
# Define Attention layer

# %%
class BahdanauAttention(tf.keras.Model):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)

    def call(self, query, values):
        # query shape == (batch_size, hidden size)
        # hidden_with_time_axis shape == (batch_size, 1, hidden size)
        # we are doing this to perform addition to calculate the score
        hidden_with_time_axis = tf.expand_dims(query, 1)

        # score shape == (batch_size, max_length, 1)
        # we get 1 at the last axis because we are applying score to self.V
        # the shape of the tensor before applying self.V is (batch_size, max_length, units)
        score = self.V(tf.nn.tanh(self.W1(values) + self.W2(hidden_with_time_axis)))

        # attention_weights shape == (batch_size, max_length, 1)
        attention_weights = tf.nn.softmax(score, axis=1)

        # context_vector shape == (batch_size, max_length, hidden_size)
        context_vector = attention_weights * values
        
        # context_vector shape after sum == (batch_size, hidden_size)
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %%
attention_layer = BahdanauAttention(10)
attention_result, attention_weights = attention_layer(sample_hidden, sample_output)

print("Attention result shape: (batch size, units) {}".format(attention_result.shape))
print("Attention weights shape: (batch_size, sequence_length, 1) {}".format(attention_weights.shape))
# Out:
# Attention result shape: (batch size, units) (128, 1024)
# Attention weights shape: (batch_size, sequence_length, 1) (128, 18, 1)

# %% [markdown]
# Decoder class construction

# %%
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_dim, dec_units, batch_sz):
        # vocab_size=vocab_tar_size=2494, embedding_dim=256, dec_units=1024, batch_sz=128
        super(Decoder, self).__init__()
        self.batch_sz = batch_sz
        self.dec_units = dec_units
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.dec_units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        # the dimension of the output is the vocab size, through the softmax function,
        # this layer will return the probability of each word in the dictory
        self.fc = tf.keras.layers.Dense(vocab_size)

        # used for attention
        self.attention = BahdanauAttention(self.dec_units)

    def call(self, x, hidden, enc_output):
        # This function outputs a result at each timestamp
        # The hidden state of fisrt timestamp in the decoder is 
        # the hidden state of last timestamp in the encoder
        context_vector, attention_weights = self.attention(hidden, enc_output)
        
        # x shape after passing through embedding == (batch_size, 1, embedding_dim)
        x = self.embedding(x)

        # concatenate the input x and the context_vector, as the input of the GRU
        # context_vector shape == (batch_size, units) -> (128, 1024)
        # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size) -> (128, 1, 1024 + 256)
        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

        # passing the concatenated vector to the GRU
        # get the output and state of the current timestamp
        # output shape == (batch_size, 1, units) -> (128, 1, 1024) 
        # state shape == (batch_size, units) -> (128, 1024)
        output, state = self.gru(x)

        # output shape == (batch_size, hidden_size) -> (128, 1024)
        output = tf.reshape(output, (-1, output.shape[2]))

        # output shape == (batch_size, vocab) -> (128, 2494)
        x = self.fc(output)

        return x, state, attention_weights

# %%
decoder = Decoder(vocab_tar_size, embedding_dim, units, BATCH_SIZE)
sample_decoder_output, _, _ = decoder(tf.random.uniform((BATCH_SIZE, 1)), sample_hidden, sample_output)
print('Decoder output shape: (batch_size, vocab size) {}'.format(sample_decoder_output.shape))
# Out:
# Decoder output shape: (batch_size, vocab size) (128, 2494)

# %% [markdown]
# Define optimizer and loss function

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

def loss_function(real, pred):
    """Calculate the loss value
    Args:
        real: the true label  shape == (batch_size,) -> (128,)
        pred: the probability of each word from the vocabulary, is the output from the decoder 
                 shape == (batch_size, vocab_size) -> (128, 6082)

    Returns: 
        the average loss of the data in a batch size
    """
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %% [markdown]
# Checkpoints saving

# %%
checkpoint_dir = './checkpoints/tcn-eng'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 encoder=encoder,
                                 decoder=decoder)

# %% [markdown]
# Define Training

# %%
@tf.function
def train_step(inp, targ, enc_hidden):
    loss = 0

    with tf.GradientTape() as tape:
        enc_output, enc_hidden = encoder(inp, enc_hidden)

        dec_hidden = enc_hidden
        
        # feed the <start> as the first input of the decoder
        # dec input shape == (batch_size, 1) -> (128, 1)
        dec_input = tf.expand_dims([targ_lang.word_index['<start>']] * BATCH_SIZE, 1)

        # Teacher forcing - feeding the target as the next input
        # because of the data preprocessing(add a start token to the sentence)
        # the first word is <start>, so t starts from 1(not 0)
        for t in range(1, targ.shape[1]):
            # passing enc_output to the decoder
            predictions, dec_hidden, _ = decoder(dec_input, dec_hidden, enc_output)

            # targ[:, t] is the true label(index of the word) of every sentence(in a batch) 
            # at the current timestamp
            # like [  85   18   25   25  ···  1047   79   13], shape == (batch_size,) -> (128,)
            # predictions shape == (batch_size, vocab_size) -> (128, 6082)
            loss += loss_function(targ[:, t], predictions)

            # using teacher forcing
            dec_input = tf.expand_dims(targ[:, t], 1)

    batch_loss = (loss / int(targ.shape[1]))

    # collect all trainable variables
    variables = encoder.trainable_variables + decoder.trainable_variables

    # calculate the gradients for the whole variables
    gradients = tape.gradient(loss, variables)

    # apply the gradients on the variables
    optimizer.apply_gradients(zip(gradients, variables))

    return batch_loss

# %%
EPOCHS = 100

for epoch in range(EPOCHS):
    start = time.time()

    # get the initial hidden state of gru
    enc_hidden = encoder.initialize_hidden_state()
    total_loss = 0

    for (batch, (inp, targ)) in enumerate(dataset.take(steps_per_epoch)):
        batch_loss = train_step(inp, targ, enc_hidden)
        total_loss += batch_loss

        if batch % 100 == 0:
            print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1,
                                                         batch,
                                                         batch_loss.numpy()))

    # saving (checkpoint) the model every 5 epochs
    if (epoch + 1) % 5 == 0:
        checkpoint.save(file_prefix=checkpoint_prefix)
        
    print('Epoch {} Loss {:.4f}'.format(epoch + 1, total_loss / steps_per_epoch))
    print('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# 2025-03-11 17:01:10.440873: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1 Batch 0 Loss 3.9756
# Epoch 1 Loss 3.8731
# Time taken for 1 epoch 27.74392604827881 sec
#
# Epoch 2 Batch 0 Loss 3.8295
# Epoch 2 Loss 3.7110
# Time taken for 1 epoch 14.016651630401611 sec
#
# Epoch 3 Batch 0 Loss 3.4079
# Epoch 3 Loss 3.4706
# Time taken for 1 epoch 14.622299194335938 sec
#
# Epoch 4 Batch 0 Loss 3.4956
# Epoch 4 Loss 3.3956
# Time taken for 1 epoch 15.022383689880371 sec
#
# Epoch 5 Batch 0 Loss 3.2452
# Epoch 5 Loss 3.3492
# Time taken for 1 epoch 14.500324010848999 sec
#
# Epoch 6 Batch 0 Loss 3.3148
# Epoch 6 Loss 3.3049
# Time taken for 1 epoch 16.9169340133667 sec
#
# Epoch 7 Batch 0 Loss 3.1949
# Epoch 7 Loss 3.2631
# Time taken for 1 epoch 18.21966290473938 sec
#
# Epoch 8 Batch 0 Loss 3.1386
# Epoch 8 Loss 3.2259
# Time taken for 1 epoch 15.763952016830444 sec
#
# Epoch 9 Batch 0 Loss 3.2027
# Epoch 9 Loss 3.1731
# Time taken for 1 epoch 17.889650106430054 sec
#
# Epoch 10 Batch 0 Loss 3.2285
# Epoch 10 Loss 3.1325
# Time taken for 1 epoch 14.284749031066895 sec
#
# Epoch 11 Batch 0 Loss 3.0848
# Epoch 11 Loss 3.0834
# Time taken for 1 epoch 14.210677146911621 sec
#
# Epoch 12 Batch 0 Loss 2.9958
# Epoch 12 Loss 3.0377
# Time taken for 1 epoch 14.025134086608887 sec
#
# Epoch 13 Batch 0 Loss 2.8470
# Epoch 13 Loss 2.9704
# Time taken for 1 epoch 13.880193948745728 sec
#
# Epoch 14 Batch 0 Loss 2.8272
# Epoch 14 Loss 2.8964
# Time taken for 1 epoch 13.893682956695557 sec
#
# Epoch 15 Batch 0 Loss 2.7300
# Epoch 15 Loss 2.8476
# Time taken for 1 epoch 14.738669157028198 sec
#
# Epoch 16 Batch 0 Loss 2.7916
# Epoch 16 Loss 2.7682
# Time taken for 1 epoch 14.210623979568481 sec
#
# Epoch 17 Batch 0 Loss 2.7695
# Epoch 17 Loss 2.6929
# Time taken for 1 epoch 16.639113187789917 sec
#
# Epoch 18 Batch 0 Loss 2.6798
# Epoch 18 Loss 2.6086
# Time taken for 1 epoch 17.287397861480713 sec
#
# Epoch 19 Batch 0 Loss 2.5328
# Epoch 19 Loss 2.5335
# Time taken for 1 epoch 16.379682064056396 sec
#
# Epoch 20 Batch 0 Loss 2.3957
# Epoch 20 Loss 2.4513
# Time taken for 1 epoch 14.16857385635376 sec
#
# Epoch 21 Batch 0 Loss 2.2858
# Epoch 21 Loss 2.3489
# Time taken for 1 epoch 13.963311195373535 sec
#
# Epoch 22 Batch 0 Loss 2.3024
# Epoch 22 Loss 2.2513
# Time taken for 1 epoch 13.645617008209229 sec
#
# Epoch 23 Batch 0 Loss 2.1202
# Epoch 23 Loss 2.1415
# Time taken for 1 epoch 13.868760108947754 sec
#
# Epoch 24 Batch 0 Loss 2.1051
# Epoch 24 Loss 2.0365
# Time taken for 1 epoch 14.08384895324707 sec
#
# Epoch 25 Batch 0 Loss 1.9382
# Epoch 25 Loss 1.9268
# Time taken for 1 epoch 14.25639796257019 sec
#
# Epoch 26 Batch 0 Loss 1.7706
# Epoch 26 Loss 1.8182
# Time taken for 1 epoch 14.233964920043945 sec
#
# Epoch 27 Batch 0 Loss 1.7445
# Epoch 27 Loss 1.7057
# Time taken for 1 epoch 14.480565071105957 sec
#
# Epoch 28 Batch 0 Loss 1.6080
# Epoch 28 Loss 1.6063
# Time taken for 1 epoch 13.712054967880249 sec
#
# Epoch 29 Batch 0 Loss 1.4889
# Epoch 29 Loss 1.5092
# Time taken for 1 epoch 13.462060689926147 sec
#
# Epoch 30 Batch 0 Loss 1.3997
# Epoch 30 Loss 1.4200
# Time taken for 1 epoch 13.671819925308228 sec
#
# Epoch 31 Batch 0 Loss 1.3041
# Epoch 31 Loss 1.3212
# Time taken for 1 epoch 13.43378496170044 sec
#
# Epoch 32 Batch 0 Loss 1.2757
# Epoch 32 Loss 1.2428
# Time taken for 1 epoch 13.354166030883789 sec
#
# Epoch 33 Batch 0 Loss 1.1728
# Epoch 33 Loss 1.1665
# Time taken for 1 epoch 13.900077104568481 sec
#
# Epoch 34 Batch 0 Loss 1.1211
# Epoch 34 Loss 1.1030
# Time taken for 1 epoch 13.374813079833984 sec
#
# Epoch 35 Batch 0 Loss 1.0302
# Epoch 35 Loss 1.0384
# Time taken for 1 epoch 13.4895761013031 sec
#
# Epoch 36 Batch 0 Loss 0.9430
# Epoch 36 Loss 0.9815
# Time taken for 1 epoch 13.309490203857422 sec
#
# Epoch 37 Batch 0 Loss 0.9551
# Epoch 37 Loss 0.9437
# Time taken for 1 epoch 13.383328914642334 sec
#
# Epoch 38 Batch 0 Loss 0.8803
# Epoch 38 Loss 0.8874
# Time taken for 1 epoch 13.341248989105225 sec
#
# Epoch 39 Batch 0 Loss 0.8612
# Epoch 39 Loss 0.8487
# Time taken for 1 epoch 15.301417827606201 sec
#
# Epoch 40 Batch 0 Loss 0.8037
# Epoch 40 Loss 0.8048
# Time taken for 1 epoch 15.087661981582642 sec
#
# Epoch 41 Batch 0 Loss 0.7927
# Epoch 41 Loss 0.7612
# Time taken for 1 epoch 16.577963829040527 sec
#
# Epoch 42 Batch 0 Loss 0.7178
# Epoch 42 Loss 0.7239
# Time taken for 1 epoch 18.13700819015503 sec
#
# Epoch 43 Batch 0 Loss 0.6889
# Epoch 43 Loss 0.6884
# Time taken for 1 epoch 14.735920906066895 sec
#
# Epoch 44 Batch 0 Loss 0.6220
# Epoch 44 Loss 0.6626
# Time taken for 1 epoch 14.24671220779419 sec
#
# Epoch 45 Batch 0 Loss 0.6234
# Epoch 45 Loss 0.6368
# Time taken for 1 epoch 13.17040205001831 sec
#
# Epoch 46 Batch 0 Loss 0.5906
# Epoch 46 Loss 0.6131
# Time taken for 1 epoch 13.119410276412964 sec
#
# Epoch 47 Batch 0 Loss 0.5456
# Epoch 47 Loss 0.5773
# Time taken for 1 epoch 13.147709846496582 sec
#
# Epoch 48 Batch 0 Loss 0.5262
# Epoch 48 Loss 0.5477
# Time taken for 1 epoch 13.06328797340393 sec
#
# Epoch 49 Batch 0 Loss 0.5013
# Epoch 49 Loss 0.5297
# Time taken for 1 epoch 13.055809020996094 sec
#
# Epoch 50 Batch 0 Loss 0.5081
# Epoch 50 Loss 0.5064
# Time taken for 1 epoch 13.265261173248291 sec
#
# Epoch 51 Batch 0 Loss 0.4756
# Epoch 51 Loss 0.4783
# Time taken for 1 epoch 13.62734317779541 sec
#
# Epoch 52 Batch 0 Loss 0.4334
# Epoch 52 Loss 0.4516
# Time taken for 1 epoch 14.667721033096313 sec
#
# Epoch 53 Batch 0 Loss 0.4156
# Epoch 53 Loss 0.4186
# Time taken for 1 epoch 13.712212085723877 sec
#
# Epoch 54 Batch 0 Loss 0.3943
# Epoch 54 Loss 0.3918
# Time taken for 1 epoch 13.321224212646484 sec
#
# Epoch 55 Batch 0 Loss 0.3841
# Epoch 55 Loss 0.3783
# Time taken for 1 epoch 13.668111085891724 sec
#
# Epoch 56 Batch 0 Loss 0.3491
# Epoch 56 Loss 0.3544
# Time taken for 1 epoch 13.331236839294434 sec
#
# Epoch 57 Batch 0 Loss 0.3053
# Epoch 57 Loss 0.3276
# Time taken for 1 epoch 13.41692304611206 sec
#
# Epoch 58 Batch 0 Loss 0.2726
# Epoch 58 Loss 0.3051
# Time taken for 1 epoch 13.40467119216919 sec
#
# Epoch 59 Batch 0 Loss 0.2534
# Epoch 59 Loss 0.2781
# Time taken for 1 epoch 13.47809100151062 sec
#
# Epoch 60 Batch 0 Loss 0.2500
# Epoch 60 Loss 0.2643
# Time taken for 1 epoch 13.532553911209106 sec
#
# Epoch 61 Batch 0 Loss 0.2379
# Epoch 61 Loss 0.2472
# Time taken for 1 epoch 13.439582109451294 sec
#
# Epoch 62 Batch 0 Loss 0.2165
# Epoch 62 Loss 0.2339
# Time taken for 1 epoch 13.344435930252075 sec
#
# Epoch 63 Batch 0 Loss 0.1972
# Epoch 63 Loss 0.2134
# Time taken for 1 epoch 13.263733148574829 sec
#
# Epoch 64 Batch 0 Loss 0.1866
# Epoch 64 Loss 0.1977
# Time taken for 1 epoch 13.409093856811523 sec
#
# Epoch 65 Batch 0 Loss 0.1737
# Epoch 65 Loss 0.1841
# Time taken for 1 epoch 13.508356094360352 sec
#
# Epoch 66 Batch 0 Loss 0.1708
# Epoch 66 Loss 0.1767
# Time taken for 1 epoch 13.304970979690552 sec
#
# Epoch 67 Batch 0 Loss 0.1555
# Epoch 67 Loss 0.1617
# Time taken for 1 epoch 13.281427145004272 sec
#
# Epoch 68 Batch 0 Loss 0.1434
# Epoch 68 Loss 0.1496
# Time taken for 1 epoch 13.330961227416992 sec
#
# Epoch 69 Batch 0 Loss 0.1378
# Epoch 69 Loss 0.1356
# Time taken for 1 epoch 13.360183954238892 sec
#
# Epoch 70 Batch 0 Loss 0.1178
# Epoch 70 Loss 0.1277
# Time taken for 1 epoch 13.422916173934937 sec
#
# Epoch 71 Batch 0 Loss 0.1142
# Epoch 71 Loss 0.1144
# Time taken for 1 epoch 13.204061031341553 sec
#
# Epoch 72 Batch 0 Loss 0.0975
# Epoch 72 Loss 0.1020
# Time taken for 1 epoch 13.2546968460083 sec
#
# Epoch 73 Batch 0 Loss 0.0920
# Epoch 73 Loss 0.0936
# Time taken for 1 epoch 13.382811784744263 sec
#
# Epoch 74 Batch 0 Loss 0.0854
# Epoch 74 Loss 0.0869
# Time taken for 1 epoch 13.293922901153564 sec
#
# Epoch 75 Batch 0 Loss 0.0838
# Epoch 75 Loss 0.0821
# Time taken for 1 epoch 13.476551055908203 sec
#
# Epoch 76 Batch 0 Loss 0.0724
# Epoch 76 Loss 0.0764
# Time taken for 1 epoch 13.262156963348389 sec
#
# Epoch 77 Batch 0 Loss 0.0638
# Epoch 77 Loss 0.0701
# Time taken for 1 epoch 13.471016883850098 sec
#
# Epoch 78 Batch 0 Loss 0.0697
# Epoch 78 Loss 0.0660
# Time taken for 1 epoch 13.47115421295166 sec
#
# Epoch 79 Batch 0 Loss 0.0611
# Epoch 79 Loss 0.0592
# Time taken for 1 epoch 13.318665981292725 sec
#
# Epoch 80 Batch 0 Loss 0.0522
# Epoch 80 Loss 0.0566
# Time taken for 1 epoch 13.572311639785767 sec
#
# Epoch 81 Batch 0 Loss 0.0556
# Epoch 81 Loss 0.0570
# Time taken for 1 epoch 13.411582946777344 sec
#
# Epoch 82 Batch 0 Loss 0.0446
# Epoch 82 Loss 0.0522
# Time taken for 1 epoch 13.484935998916626 sec
#
# Epoch 83 Batch 0 Loss 0.0430
# Epoch 83 Loss 0.0470
# Time taken for 1 epoch 13.3014976978302 sec
#
# Epoch 84 Batch 0 Loss 0.0433
# Epoch 84 Loss 0.0441
# Time taken for 1 epoch 13.19730806350708 sec
#
# Epoch 85 Batch 0 Loss 0.0404
# Epoch 85 Loss 0.0389
# Time taken for 1 epoch 13.423366785049438 sec
#
# Epoch 86 Batch 0 Loss 0.0370
# Epoch 86 Loss 0.0358
# Time taken for 1 epoch 13.179699897766113 sec
#
# Epoch 87 Batch 0 Loss 0.0307
# Epoch 87 Loss 0.0315
# Time taken for 1 epoch 13.224159002304077 sec
#
# Epoch 88 Batch 0 Loss 0.0272
# Epoch 88 Loss 0.0287
# Time taken for 1 epoch 13.126155138015747 sec
#
# Epoch 89 Batch 0 Loss 0.0254
# Epoch 89 Loss 0.0259
# Time taken for 1 epoch 13.082014083862305 sec
#
# Epoch 90 Batch 0 Loss 0.0287
# Epoch 90 Loss 0.0239
# Time taken for 1 epoch 13.311306953430176 sec
#
# Epoch 91 Batch 0 Loss 0.0231
# Epoch 91 Loss 0.0218
# Time taken for 1 epoch 13.159177303314209 sec
#
# Epoch 92 Batch 0 Loss 0.0230
# Epoch 92 Loss 0.0201
# Time taken for 1 epoch 13.142657995223999 sec
#
# Epoch 93 Batch 0 Loss 0.0199
# Epoch 93 Loss 0.0186
# Time taken for 1 epoch 13.143199443817139 sec
#
# Epoch 94 Batch 0 Loss 0.0167
# Epoch 94 Loss 0.0177
# Time taken for 1 epoch 13.120886087417603 sec
#
# Epoch 95 Batch 0 Loss 0.0138
# Epoch 95 Loss 0.0160
# Time taken for 1 epoch 13.268430948257446 sec
#
# Epoch 96 Batch 0 Loss 0.0139
# Epoch 96 Loss 0.0151
# Time taken for 1 epoch 13.1231849193573 sec
#
# Epoch 97 Batch 0 Loss 0.0141
# Epoch 97 Loss 0.0145
# Time taken for 1 epoch 13.217957019805908 sec
#
# Epoch 98 Batch 0 Loss 0.0124
# Epoch 98 Loss 0.0136
# Time taken for 1 epoch 13.145441055297852 sec
#
# Epoch 99 Batch 0 Loss 0.0111
# Epoch 99 Loss 0.0130
# Time taken for 1 epoch 13.175890922546387 sec
#
# Epoch 100 Batch 0 Loss 0.0136
# Epoch 100 Loss 0.0125
# Time taken for 1 epoch 13.321737051010132 sec

# %% [markdown]
# Evaluation (Translation)

# %%
def evaluate(sentence):
    """Translate a sentence
    Args:
        sentence: the test sentence        
    """
    
    # max_length_targ 38, max_length_inp 64
    attention_plot = np.zeros((max_length_targ, max_length_inp))

    sentence = preprocess(sentence)

    # convert each word to the index in the test sentence
    inputs = [inp_lang.word_index[i] for i in sentence.split(' ')]
    inputs = tf.keras.preprocessing.sequence.pad_sequences([inputs],
                                                           maxlen=max_length_inp,
                                                           padding='post')

    inputs = tf.convert_to_tensor(inputs)

    result = ''

    # hidden shape == (1, 1024)
    hidden = [tf.zeros((1, units))]
    
    # enc out shape == (1, max_length_inp, 1024) -> (1, 18, 1024)
    # enc hidden shape == (1, 1024)
    enc_out, enc_hidden = encoder(inputs, hidden)

    dec_hidden = enc_hidden
    dec_input = tf.expand_dims([targ_lang.word_index['<start>']], 0)

    for t in range(max_length_targ):
        predictions, dec_hidden, attention_weights = decoder(dec_input, dec_hidden, enc_out)
        
        # storing the attention weigths to plot later on
        attention_weights = tf.reshape(attention_weights, (-1, ))
        attention_plot[t] = attention_weights.numpy()

        # get the index which has the highest probability
        predicted_id = tf.argmax(predictions[0]).numpy()
        #  convert the index to the word
        result += targ_lang.index_word[predicted_id] + ' '

        # when the decoder predicts the end, stop prediction
        if targ_lang.index_word[predicted_id] == '<end>':
            return result, sentence, attention_plot

        # the predicted id is fed back into the model
        dec_input = tf.expand_dims([predicted_id], 0)

    return result, sentence, attention_plot


def translate(sentence):
    result, sentence, attention_plot= evaluate(sentence)
    return result.rpartition('<end>')[0].strip()

# %% [markdown]
# Restore the latest checkpoint and translate test set

# %%
checkpoint_dir = './checkpoints/tcn-eng'
print(tf.train.latest_checkpoint(checkpoint_dir))

# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))
# Out:
# ./checkpoints/tcn-eng/ckpt-20

# %%
test_set = pd.read_csv('./preprocessed/cleaned_test_tcn.csv').drop('split', axis=1)

# %%
test_set
# Out:
#                                                    text  \
# 0                         【PolarStar】美麗諾羊毛保暖襪『淺灰』P18634
# 1                                  甜蜜水晶~天然水晶五行珠手鍊10mm手鍊
# 2                                             粉晶六角柱純銀項鍊
# 3                       3M SCOTCH VHB 超強力雙面膠-戶外專用 V1808
# 4                                             燈專屬優惠 *4盒
# 5     特價促銷款 NIKE 耐吉 WMNS NIKE INTERNATIONALIST JCRD ...
# 6                                    Jo Malone 禮盒(附上緞帶)
# 7                   【TORO】自然風2.7尺鞋櫃 (HX-926(胡桃) HX927雪白
# 8                                    G.P 涼鞋 黑紅 男款 no686
# 9                            【紐西蘭 Olive】橄欖嬰兒天然按摩油 100ml
# 10                            紐崔斯INFUSION天然成犬(雞肉)2.27kg
# 11         日本迪士尼 米奇米妮 米奇 攜帶式剪刀 隨身剪刀 收納剪刀 剪刀 COCOS TY180
# 29                    韓國奶油眼影霜多款可選                        韓國 奶油 眼影 霜 多款 可選
# ...                           ...                                     ...
# 9970         寶寶鞋台灣製迪士尼米奇正版寶寶嗶嗶鞋魔法          寶寶鞋 台 灣 製 迪士尼 米奇 正版 寶寶 嗶 嗶鞋 魔法
# 9971                        迷你釘書機                                  迷你 釘書機
# 9972                包屁衣男寶寶夏季連身衣魔法                      包屁衣 男寶寶 夏季 連身 衣 魔法
# 9973                        彪馬拖鞋女                                彪 馬 拖鞋 女
# 9974                      銳致車用充電器                               銳致 車用 充電器
# 9975                      創意食物手機殼                               創意 食物 手機殼
# 9976                  意大利香橼香水身体乳液                         意大利 香橼 香水 身体 乳液
# 9977                   亮麗時尚女款羽毛外套                          亮麗時 尚 女款 羽毛 外套
# 9978                    簡約清新花兒手機殼                            簡約 清新 花兒 手機殼
# 9979            多功能車用寵物安全收納袋快樂生活網                多功能 車用 寵物 安全 收納袋 快樂 生活 網
# 9980                    蕾絲半透明輕便雨衣                           蕾 絲 半透明 輕便 雨衣
# 9981                  單肩斜背包側背包肩背包                       單肩 斜 背包 側 背包 肩 背包
# 9982                    羊羔絨素面保暖外套                           羊羔 絨 素面 保暖 外套
# 9983                 珍舒敷透氣防水薄膜敷料盒                       珍舒敷 透氣 防水 薄膜 敷料 盒
# 9984               德國珍寶水晶蝦專用水質穩定劑                    德國珍 寶 水晶 蝦專 用水 質 穩定劑
# 9985                      藍牙喇叭叢林綠                               藍牙 喇叭 叢林綠
# 9986           超值入多功能汽車遮陽板眼鏡夾顏色隨機              超值 入 多功能 汽車 遮陽 板眼 鏡 夾顏色 隨機
# 9987                       金四季寵物窩                               金 四季 寵物 窩
# 9988           幫寶適一級幫紙尿褲尿布片日本原裝箱購              幫寶適 一級 幫紙 尿褲 尿布 片 日本 原裝 箱購
# 9989                  針織外套單排扣開衫外套                        針織 外套 單排 扣 開衫 外套
# 9990            超大棉麻衣物雙開收納箱儲物箱整理盒                 超大 棉麻 衣物 雙開 收納箱 儲物箱 整理盒
# 9991                        人生不漸凍                                 人生 不漸 凍
# 9992                   白金鋼珠筆原子筆對筆                           白金 鋼珠筆 原子 筆對筆
# 9993                      潔保五層效率櫃                               潔保五層 效率 櫃
# 9994     型腿部瘦身按摩輪美體按摩器腿部臀部手臂美體按摩器      型 腿部 瘦身 按摩 輪美體 按摩器 腿部 臀部 手臂 美體 按摩器
# 9995              後背包公事包筆電包丹麥品牌白色                   後 背包 公事包 筆電 包丹麥 品牌 白色
# 9996                    凉鞋童鞋深蓝色中童                            凉鞋 童鞋 深蓝色 中童
# 9997         迪士尼行動電源泰瑞鴨迪士尼鴨嘴獸泰瑞充電           迪士尼 行動 電源 泰瑞 鴨 迪士尼 鴨 嘴獸 泰瑞 充電
# 9998               達爾文設計製圖鉛筆鐵盒支設計                達爾文設 計 製 圖 鉛 筆 鐵 盒 支 設 計
# 9999                     運動磁吸藍芽耳機                             運動 磁吸 藍芽 耳機
#
# [10000 rows x 3 columns]

# %%
test_tr_sents_all = []
for i in range(len(test_set['product_title_processed'])):
    try: test_tr_sents_all.append(translate(test_set['product_title_processed'][i]))
    except: test_tr_sents_all.append(np.nan)

# %%
test_tr_sents_all
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'temperament fresh practical hair band hair accessories hair hoop',
#  nan,
#  nan,
#  nan,
#  nan,
#  'apollo safe iron cabinet gold treasury library wealth lucky essential original warranty',
#  nan,
#  'streamlight survivor led flashlight',
#  nan,
#  nan,
#  nan,
#  nan,
#  'charcoal pit drawing artist yamamoto the guard dvd',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'alfastar bluetooth sports headset',
#  nan,
#  nan,
#  nan,
#  'temperament fresh practical hair band hair accessories hair hoop',
#  nan,
#  nan,
#  nan,
#  'desk bay single feet double sided cloth breathable mattress magic baby',
#  nan,
#  nan,
#  nan,
#  'nekopara vol mobile phone shell sony x xa ultra xzs xz premium',
#  'caco splicing petticoat university t female',
#  nan,
#  nan,
#  nan,
#  'htc phone case samsung case',
#  'kimo outdoor casual shoes black women',
#  'liyo v collar lace penetration',
#  nan,
#  nan,
#  'phyto hair flower plant shampoo paris d',
#  nan,
#  'crystal health series',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'sushi go kaohsiung ponzi cards kangagames',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'nike air max obsidian',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'nekopara vol mobile phone shell htc u ultra u play pro lifestyle',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'new balance tier retro shoes big o sports',
#  nan,
#  nan,
#  'lucky star dvd vol',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'crystal health series',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'temperament fresh practical hair band hair accessories hair hoop',
#  nan,
#  nan,
#  'adidas accel short sports shorts leisure shorts',
#  nan,
#  'pacific rim phone case oppo plus',
#  'casio ex selfie camera free tescom',
#  'extra natural sweet grape flavor',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'sony xperia compact premium tempered glass screen protector',
#  nan,
#  'breakout crisis dvd vol',
#  nan,
#  'jack wolfskin inflatable neck pillow',
#  nan,
#  nan,
#  nan,
#  'parker ingenuity element series elite purple rose gold clip s pen',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'adidas accel short sports shorts leisure shorts',
#  nan,
#  nan,
#  nan,
#  'adidas wild burst silicone watch black shoes',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'roush slim fit single pocket fit plain shirt',
#  nan,
#  nan,
#  nan,
#  'the fresh adult diapers m pc watsons',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'liyo v collar chiffon shirt',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'moschino fresh couture line small fresh women edt',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'hold stand type notebook cover',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'alfastar bluetooth sports headset',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'college wind small',
#  nan,
#  nan,
#  'nekopara phone shell htc u ultra u play pro lifestyle',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'carnation slim butterfly type cotton night pc',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'gap classic logo long sleeve hooded jacket child',
#  nan,
#  'breathable canvas shoes',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'nike roshe two sports shoes female',
#  'streamlight survivor led flashlight',
#  nan,
#  'fashion simple practical pillow cushion sofa decor pillow bolster',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'small buckle sealed cans fresh moisture storage tank kitchen dry food',
#  'samsung case cover full cover simple buckle phone case asus',
#  'long version',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'cotton printed pocket lunch bag',
#  'the horse',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'estee lauder young cream',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  '',
#  nan,
#  'kikiko action professional sport swimming goggles blue',
#  nan,
#  nan,
#  nan,
#  nan,
#  'nike jordan flight runner basketball shoes men s big o sports',
#  nan,
#  nan,
#  'kgh canvas tote pack',
#  'japan soup small clay pot casserole a',
#  'the culture japan imported round top space craft diamond sc mk',
#  nan,
#  nan,
#  nan,
#  'new balance sports shoes black shoes',
#  nan,
#  nan,
#  nan,
#  nan,
#  'skechers women big o sportsnike',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'desk bay single feet double sided cloth breathable mattress magic baby',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'htc ultra desire pro evo cartoon cat rhinestone shell',
#  nan,
#  nan,
#  'airpillow samsung note note full air cushion clear transparent back cover',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'tide laundry soap',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'dayneeds five paint outdoor canvas shoes big o sports',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'crystal music series crystal health dietary fiber pack',
#  'tory burch cute navy wind anchor totem straw loafers',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'coach cute big o sports',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'nike lebron xiii low bg basketball shoes men s big o sports',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'breathable canvas harajuku thick bottom increased pink white',
#  nan,
#  nan,
#  nan,
#  nan,
#  'nike wmns roshe two sports shoes big o sports',
#  nan,
#  nan,
#  'swarovski sterling silver bracelet',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'transcend microsdhc memory card',
#  nan,
#  nan,
#  nan,
#  'disney sweet sour plain leather strap casual shoes magic baby',
#  'infant soft along the magic baby',
#  nan,
#  nan,
#  nan,
#  'youth winter plus velvet thick bristles very warm hooded youth version',
#  nan,
#  nan,
#  nan,
#  nan,
#  'skechers women when high running shoes',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'liyo v collar chiffon shirt',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'longchamp le pliage neo high density nylon backpack medium',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'college wind small leather shoes',
#  nan,
#  'cloud story the vol',
#  nan,
#  nan,
#  nan,
#  nan,
#  'adidas d rose englewood iv td basketball shoes men',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'asics arthur s gel nimbus lite show top running shoes men big o sportsasics',
#  nan,
#  nan,
#  nan,
#  'magic baby children hat magic baby',
#  'nike air berwuda prm retro sports shoes male big o sports',
#  'college wind shoulder bucket pack black',
#  nan,
#  nan,
#  nan,
#  'cat playground jungle series',
#  nan,
#  'ifairies large size long sleeve t shirt s belt',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'roush slim fit plain leather litchi pattern weave pack',
#  nan,
#  nan,
#  nan,
#  nan,
#  'mr bubble phone case sony x xa ultra xzs xz xzp compact',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'tree de sc multifunctional locker',
#  nan,
#  nan,
#  'mizuno wave inspire men running shoes big o sports',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'nike air max obsidian',
#  'adidas d rose englewood iv td basketball shoes women',
#  nan,
#  nan,
#  nan,
#  nan,
#  '',
#  'high density yoga brick eva yoga brick pcs',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'swarovski original licensed asus zenfone inch silicone case',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'germany hamptons wok pan series',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'moonstar hiking shoes sneakers brown shoes men s shoes',
#  'summer fresh leaves phone case classic plain leather case',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'self card folder box',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'perfect cut line shape socks',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'ifairies shoulder messenger bag shoulder bag',
#  nan,
#  'japan holbein heavy body colors acrylic paint',
#  nan,
#  'american kid o traffic series puff car blue',
#  nan,
#  nan,
#  'college wind small puzi',
#  nan,
#  nan,
#  'couple short tee army women',
#  nan,
#  nan,
#  nan,
#  nan,
#  'desk bay multifunction warmer small roll pillow magic baby _ b',
#  nan,
#  nan,
#  nan,
#  nan,
#  'perfect cut korean fashion inner fur coat',
#  nan,
#  'twice phone case for asus zenfone selfie go',
#  nan,
#  nan,
#  nan,
#  'bubble airbag cushion phone holder catcher',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'adidas originals superstar w leather shoulder',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'adidas d rose englewood iv td basketball shoes men',
#  nan,
#  'goospery apple iphone plus pudding case soft cover',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'toy eyes m pack',
#  nan,
#  nan,
#  nan,
#  nan,
#  'disney girls dress',
#  nan,
#  nan,
#  'poli bonny rescue hero robocar sandals blue cases',
#  nan,
#  '',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'baby shoes infant anti slip prewalker magic baby',
#  nan,
#  nan,
#  nan,
#  'nike air zoom pegasus running shoes',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'scale cm',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'nike lebron xiii low bg basketball shoes women big o sportsnike',
#  nan,
#  'perfect cut big face cat cushion pillow',
#  nan,
#  nan,
#  nan,
#  'mr building progressive rubber pen f pcs',
#  nan,
#  nan,
#  nan,
#  'usa fat cat grass toy',
#  nan,
#  nan,
#  nan,
#  'ifairies shoulder messenger bag shoulder bag',
#  nan,
#  nan,
#  'lock upper cover',
#  nan,
#  nan,
#  nan,
#  'skechers skech air infinity fashion casual series male big o sports',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'longchamp le pliage neo high density nylon backpack medium',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'ifairies large size dress',
#  nan,
#  nan,
#  nan,
#  'pokemon go pikachu case edge plus',
#  nan,
#  'nike wmns nike lunarglide jogging shoes female big o sportsnike',
#  nan,
#  nan,
#  'hater snapback velvet cap flannel snapback black',
#  nan,
#  'new balance series running shoes boy',
#  nan,
#  nan,
#  nan,
#  nan,
#  'japan imported yohaku',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'bmw genuine diamond sc',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'korean made thick straps cross vest',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'kimo outdoor casual shoes black shoes',
#  'amiss personality totem key tattoo tights peach flowers cat',
#  nan,
#  'slippers soft q cushioning comfortable slippers magic baby',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'sony xperia compact premium tempered glass screen protector',
#  nan,
#  nan,
#  nan,
#  'nike cheyenne premium casual shoes child',
#  nan,
#  'nike air berwuda prm retro sports shoes big o sports',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'hole bow lazy shoes',
#  nan,
#  'yu germany computer printing label grid pcs pack',
#  'waterproof bamboo charcoal flat british fashion casual tops white',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'love tyrant phone shell sony plus apple',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'coach full air cushion powder',
#  nan,
#  nan,
#  'ifairies coin pack',
#  nan,
#  nan,
#  'skechers on the go glide casual shoes dark coffee shoes',
#  nan,
#  'hario tca filter f tca',
#  nan,
#  'fashion girls dress magic baby',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'drink tea black bean',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'white gold adjustable wind small shop',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'baby shoes infant anti slip prewalker magic baby',
#  'the shu min repair moisturizing essence',
#  nan,
#  nan,
#  nan,
#  ...]

# %%
test_set['prediction'] = test_tr_sents_all

# %%
test_set
# Out:
#                                                    text  \
# 0                         【PolarStar】美麗諾羊毛保暖襪『淺灰』P18634
# 1                                  甜蜜水晶~天然水晶五行珠手鍊10mm手鍊
# 2                                             粉晶六角柱純銀項鍊
# 3                       3M SCOTCH VHB 超強力雙面膠-戶外專用 V1808
# 4                                             燈專屬優惠 *4盒
# 5     特價促銷款 NIKE 耐吉 WMNS NIKE INTERNATIONALIST JCRD ...
# 6                                    Jo Malone 禮盒(附上緞帶)
# 7                   【TORO】自然風2.7尺鞋櫃 (HX-926(胡桃) HX927雪白
# 8                                    G.P 涼鞋 黑紅 男款 no686
# 9                            【紐西蘭 Olive】橄欖嬰兒天然按摩油 100ml
# 10                            紐崔斯INFUSION天然成犬(雞肉)2.27kg
# 11         日本迪士尼 米奇米妮 米奇 攜帶式剪刀 隨身剪刀 收納剪刀 剪刀 COCOS TY180
# 29                    韓國奶油眼影霜多款可選                        韓國 奶油 眼影 霜 多款 可選
# ...                           ...                                     ...
# 9970         寶寶鞋台灣製迪士尼米奇正版寶寶嗶嗶鞋魔法          寶寶鞋 台 灣 製 迪士尼 米奇 正版 寶寶 嗶 嗶鞋 魔法
# 9971                        迷你釘書機                                  迷你 釘書機
# 9972                包屁衣男寶寶夏季連身衣魔法                      包屁衣 男寶寶 夏季 連身 衣 魔法
# 9973                        彪馬拖鞋女                                彪 馬 拖鞋 女
# 9974                      銳致車用充電器                               銳致 車用 充電器
# 9975                      創意食物手機殼                               創意 食物 手機殼
# 9976                  意大利香橼香水身体乳液                         意大利 香橼 香水 身体 乳液
# 9977                   亮麗時尚女款羽毛外套                          亮麗時 尚 女款 羽毛 外套
# 9978                    簡約清新花兒手機殼                            簡約 清新 花兒 手機殼
# 9979            多功能車用寵物安全收納袋快樂生活網                多功能 車用 寵物 安全 收納袋 快樂 生活 網
# 9980                    蕾絲半透明輕便雨衣                           蕾 絲 半透明 輕便 雨衣
# 9981                  單肩斜背包側背包肩背包                       單肩 斜 背包 側 背包 肩 背包
# 9982                    羊羔絨素面保暖外套                           羊羔 絨 素面 保暖 外套
# 9983                 珍舒敷透氣防水薄膜敷料盒                       珍舒敷 透氣 防水 薄膜 敷料 盒
# 9984               德國珍寶水晶蝦專用水質穩定劑                    德國珍 寶 水晶 蝦專 用水 質 穩定劑
# 9985                      藍牙喇叭叢林綠                               藍牙 喇叭 叢林綠
# 9986           超值入多功能汽車遮陽板眼鏡夾顏色隨機              超值 入 多功能 汽車 遮陽 板眼 鏡 夾顏色 隨機
# 9987                       金四季寵物窩                               金 四季 寵物 窩
# 9988           幫寶適一級幫紙尿褲尿布片日本原裝箱購              幫寶適 一級 幫紙 尿褲 尿布 片 日本 原裝 箱購
# 9989                  針織外套單排扣開衫外套                        針織 外套 單排 扣 開衫 外套
# 9990            超大棉麻衣物雙開收納箱儲物箱整理盒                 超大 棉麻 衣物 雙開 收納箱 儲物箱 整理盒
# 9991                        人生不漸凍                                 人生 不漸 凍
# 9992                   白金鋼珠筆原子筆對筆                           白金 鋼珠筆 原子 筆對筆
# 9993                      潔保五層效率櫃                               潔保五層 效率 櫃
# 9994     型腿部瘦身按摩輪美體按摩器腿部臀部手臂美體按摩器      型 腿部 瘦身 按摩 輪美體 按摩器 腿部 臀部 手臂 美體 按摩器
# 9995              後背包公事包筆電包丹麥品牌白色                   後 背包 公事包 筆電 包丹麥 品牌 白色
# 9996                    凉鞋童鞋深蓝色中童                            凉鞋 童鞋 深蓝色 中童
# 9997         迪士尼行動電源泰瑞鴨迪士尼鴨嘴獸泰瑞充電           迪士尼 行動 電源 泰瑞 鴨 迪士尼 鴨 嘴獸 泰瑞 充電
# 9998               達爾文設計製圖鉛筆鐵盒支設計                達爾文設 計 製 圖 鉛 筆 鐵 盒 支 設 計
# 9999                     運動磁吸藍芽耳機                             運動 磁吸 藍芽 耳機
#
#                                              prediction
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14    temperament fresh practical hair band hair acc...
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19    apollo safe iron cabinet gold treasury library...
# 20                                                  NaN
# 21                  streamlight survivor led flashlight
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26    charcoal pit drawing artist yamamoto the guard...
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 9970                                                NaN
# 9971              hario black vacuum insulation pot vhs
# 9972                                                NaN
# 9973                                                NaN
# 9974                                                NaN
# 9975                                                NaN
# 9976                                                NaN
# 9977                                                NaN
# 9978                                                NaN
# 9979                                                NaN
# 9980                                                NaN
# 9981       ifairies shoulder messenger bag shoulder bag
# 9982                                                NaN
# 9983                                                NaN
# 9984                                                NaN
# 9985                                                NaN
# 9986                                                NaN
# 9987                                                NaN
# 9988                                                NaN
# 9989                                                NaN
# 9990                                                NaN
# 9991                                                NaN
# 9992                                                NaN
# 9993                                                NaN
# 9994                                                NaN
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                             diy cut bangs artifact
#
# [10000 rows x 4 columns]

# %%
test_set.isna().sum()
# Out:
# text                          0
# product_title_clean          72
# product_title_processed      72
# prediction                 8606
# dtype: int64

# %%
test_set.dropna(inplace=True)
test_set
# Out:
#                                                    text  \
# 14                                   時尚氣質清新實用髮帶 髮飾 髮箍94
# 19            阿波羅保險箱 保險櫃 鐵櫃 金庫 財庫 財神 招財必備 公司原廠保固 600ALD
# 21                                       國際牌 CR-1632/1B
# 26                 Abercrombie & Fitch A&F 經典logo刺繡連帽外套
# 38    GOR ASUS ZenFone 3 2 Deluxe Ultra Zoon Max Las...
# 42                                   時尚氣質清新實用髮帶 髮飾 髮箍51
# 46                           台灣製雙人5x6尺透氣床墊 魔法baby~u3104
# 50        NIKE AIR MAX 98 TRIPLE WHITE 皮革 網布 640744-106
# 51    美津浓 Mizuno MAXIMIZER 21 慢跑鞋 黑色 男鞋 K1GA190209 n...
# 55    創意 iPhone8 iPhone7 Plus i7 i8 手機殼 掛繩 全包防摔 PH01214
# 56                        native PALMER 拖鞋 白色 男女鞋 no630
# 57                Abercrombie & Fitch 經典logo刺繡POLO衫 (男)
# 60                   PHYTO 髮朵 植物洗髮精(125ml / 200ml)【巴黎丁】
# 62                                            新款雪紡碎花吊帶裙
# 74               亮面螢幕保護貼 LG Optimus GJ E975w 保護貼 亮貼 亮面貼
# 82            Skechers 女 Flex Appeal 2.0 慢跑鞋- 12756WBKW
# 95     GOT7手機殼ZENFONE4 MAX SELFIE PRO ZENFONE AR 4 4S 3
# 103   New Balance 紐巴倫 TIER 3 復古鞋 童 KV996NGY Big-O Sp...
# 106                    韓國LaPalette指甲剪(小) (454347)【UR8D】
# 116                                彩色條紋性感針織吊帶-SmallPuzi
# 122                                  時尚氣質清新實用髮帶 髮飾 髮箍77
# 125   ADIDAS 愛迪達 ROSE ICON SHORT 籃球短褲 運動短褲 男 AZ4038 ...
# 127   環太平洋手機殼LG G4 G5 G6 K8 K10 K4 V10 V20 2017版 Sty...
# 128        Bread & Boxers Men's Long Sleeve relaxed（深藍）
# 129                              Baby Veil 香氛寶貝 髮香噴霧80g
# 142   BLUE POWER Google pixel/pixel XL 9H鋼化玻璃保護貼 0.33mm
# 9888  adidas d rose englewood iv td basketball shoes...
# 9891        amiss exclusive japanese classic size peach
# 9893  sony xperia compact premium tempered glass scr...
# 9899                              nike air max obsidian
# 9903    japan gatsby styling hair cream strong adhesive
# 9904                        clean keep cp card ink wine
# 9912              alfastar fashion wood in ear earphone
# 9920  fashion wild cat mini small shoulder pack incl...
# 9925         nike pro clsc pad tidl mlt bra sport shoes
# 9935                 watanabe health dietary fiber pack
# 9936  nike jordan flight runner basketball shoes men...
# 9942
# 9945  desk bay single feet double sided cloth breath...
# 9954          sushi go kaohsiung ponzi cards kangagames
# 9963              alfastar fashion wood in ear earphone
# 9967                            breathable canvas shoes
# 9969  fashion simple practical pillow cushion sofa d...
# 9971              hario black vacuum insulation pot vhs
# 9981       ifairies shoulder messenger bag shoulder bag
# 9999                             diy cut bangs artifact
#
# [1394 rows x 4 columns]

# %%
test_set.to_csv('./output/1_NMT_test_output1.csv', index=False, encoding='utf_8_sig')

# %% [markdown]
# Translate DEV set for BLEU Score Evaluation

# %%
tcn_clean
# Out:
#                                                   text    split  \
# 0                  OPPO A75 A75s A73 手机壳 软壳 挂绳壳 大眼兔硅胶壳  private
# 1                                  SOFT 99 鍍膜車蠟(強力撥水型)  private
# 2                                       低糖芒果乾 250g 臻御行  private
# 3    ＊小徑文化＊日本進口ROUND TOP space craft - diamond (SC-...  private
# 4            Hello Kitty 凱蒂貓 KITTY 涼鞋 童鞋 白/紅色 小童 no739  private
# 5                      雷鳥 LT-234 日式木紋桌墊 45 x 60 cm / 片  private
# 6                                       狂砂小子DVD VOL-08  private
# 7                    ANACOMDA 巨蟒 T1 泰坦系列 120GB SSD固態硬碟  private
# 8                          iFairies 單肩斜背包側背包肩背包【49146】  private
# 9                                      大雪山農場 山苦瓜茶20包/盒  private
# 10                                        高露潔 雙效潔淨牙刷單支  private
# 11                       Apieu Color Lip Pencil MATT絲緞  private
# 12                                         芮菲客米蘭玫瑰金鋼珠筆  private
# 13                                 海底總動員2 玻璃磁鐵 多莉款_野獸國  private
# 14                 natural甘草瓜子160g 南瓜子150g Shopping168  private
# 15                               PAPAGO 368miniHD行車記錄器  private
# 16                                 ISTA 伊士達 4分濾網頭 2pcs  private
# 17   DOT聚點 Adidas Essentials Chest Logo 方形 方塊 灰藍 連帽...  private
# 18                              流蘇立體縫線莫卡辛鞋 藍/黑色【DF337】  private
# 19                                    新品時尚可愛寶寶繡花連衣裙 洋裝  private
# 20                                客制化 泡泡气囊气垫手机支架 捕梦网羽毛  private
# 21                                    PRADA 機器人印花尼龍手拿包  private
# 22                    Imarflex 伊玛2公升#304不锈钢快煮壶 IK-2006  private
# 23                  CASIO EX-TR80 TR80 送TESCOM TTH2610  private
# 24                                 日系羊毛混紡保暖堆堆帽 貝雷帽 毛線帽  private
# 25                   日本AZZEEN芝研 植萃皇后化妝水500ml(2款)【UR8D】  private
# 26        德爾斐神諭 THE ORACLE OF DELPHI 繁體中文版 高雄龐奇桌遊 新天鵝堡  private
# 27                          MAX TEA印尼拉茶 25g*30包 可超取峇里島  private
# 28                               教育之友 Dear Baby成人舒壓著色本  private
# 29                    破盤出清★短褲 顯瘦休閒熱褲★ifairies【SM24454】  private
# ..                                                 ...      ...
# 970  NIKE 耐吉 WMNS NIKE AIR ZOOM PEGASUS 34 高階慢跑鞋 女 ...  private
# 971                     達墨TOPMORE STone 雙USB車用充電器 3.1A  private
# 972                           Keith純鈦 Ti5312兒童湯匙叉子／鈦餐具  private
# 973   MERRELL MOAB FST 2 GTX 多功能鞋 深绿色 男鞋 ML77447 no924  private
# 974                              LIYO理優英文拼字釘珠上衣E722023  private
# 975                              白金牌可調式鋼筆用墨水*INKM-1200  private
# 976                                    🎀真皮女用小手提/斜背二用包🎀  private
# 977                              多功能觸摸自行車 單車 腳踏車前包s125  private
# 978                                 SunnyQ-透氣網紗閃鑽懶人鞋．藍  private
# 979                             iFairies 鋯石流蘇耳環【33531】  private
# 980  泰勒絲Taylor Swift手機殼SONY Z2 Z3 + Z5 COMPACT M4 M...  private
# 981                                美國 Kid O 交通系列-噗噗車-藍  private
# 982                   光華 GHN-3621 二聯直式非碳紙複寫估價 20本入 / 包  private
# 983              NEW BALANCE 247 全白色 袜套 复古休闲鞋 MRL247DD  private
# 984                          紐頓 S6成犬 雞肉南瓜 2.72KG【寶羅寵品】  private
# 985                                 120x45x150三層烤漆沖孔鐵架  private
# 986                 Sanrio三麗鷗 指環扣 手機支架_Hello Kitty大頭系列  private
# 987                              學院風百搭蕾絲花邊抽繩短褲-M051058  private
# 988                                側背包 斜背包 真皮菱格包 QSF包包  private
# 989                               【自然補給】膠原玫肌凍飲 200ml/瓶  private
# 990                                           桐木砂-玫瑰6L  private
# 991                           冰雪奇緣 白雪森林 藍 卡通睡袋 台灣製 迪士尼  private
# 992                             潔保 CP-820C-2H 公共排椅 / 組  private
# 993                       加拿大 3 Sprouts 收納箱-兔子 台灣授權代理商  private
# 994                  力大牌 ABEL 66189 A4橫式板夾(顏色隨機出貨) / 個  private
# 995                【HippoRed】撕破乐趣★独特风格★中直筒牛仔裤 O591_445  private
# 996                      兒童套裝 台灣製薄長袖居家套裝 魔法Baby~k60092  private
# 997                 LONGCHAMP Le Pliage Neo高密尼龍後背包(中型)  private
# 998            iFairies 開口可調節戒指★ifairies【56472】【56472】  private
# 999                        PolarStar 女 排汗快干T恤『黑』P18102  private
#
#       product_title_clean        product_title_processed
# 0          手机壳软壳挂绳壳大眼兔硅胶壳         手机 壳 软壳 挂绳 壳 大眼 兔 硅胶 壳
# 1               鍍膜車蠟強力撥水型                   鍍膜車 蠟 強力 撥水型
# 2                低糖芒果乾臻御行                    低糖 芒果乾 臻 御行
# 3                小徑文化日本進口                    小徑 文化 日本 進口
# 4            凱蒂貓涼鞋童鞋白紅色小童               凱蒂貓 涼鞋 童鞋 白紅色 小童
# 5               雷鳥日式木紋桌墊片                   雷鳥 日式 木紋 桌墊片
# 6                    狂砂小子                          狂砂 小子
# 7              巨蟒泰坦系列固態硬碟                 巨蟒 泰坦 系列 固態 硬碟
# 983            全白色袜套复古休闲鞋                 全 白色 袜套 复古 休闲鞋
# 984          紐頓成犬雞肉南瓜寶羅寵品               紐頓 成犬 雞肉 南瓜 寶羅寵品
# 985              三層烤漆沖孔鐵架                   三層 烤 漆 沖 孔鐵架
# 986        三麗鷗指環扣手機支架大頭系列            三麗鷗 指環扣 手機 支架 大頭 系列
# 987         學院風百搭蕾絲花邊抽繩短褲              學院 風百搭蕾 絲花邊 抽繩 短褲
# 988         側背包斜背包真皮菱格包包包           側 背包 斜 背包 真皮 菱格 包包 包
# 989           自然補給膠原玫肌凍飲瓶               自然 補給 膠原 玫 肌凍 飲瓶
# 990                 桐木砂玫瑰                        桐木 砂 玫瑰
# 991   冰雪奇緣白雪森林藍卡通睡袋台灣製迪士尼  冰雪 奇緣 白雪 森林 藍 卡通 睡袋 台 灣 製 迪士尼
# 992               潔保公共排椅組                     潔保 公共 排椅 組
# 993       加拿大收納箱兔子台灣授權代理商           加拿大 收納箱 兔子 台灣 授權 代理商
# 994        力大牌橫式板夾顏色隨機出貨個           力 大牌 橫式 板 夾顏色 隨機 出貨個
# 995        撕破乐趣独特风格中直筒牛仔裤           撕破 乐趣 独特 风格 中直 筒 牛仔裤
# 996      兒童套裝台灣製薄長袖居家套裝魔法     兒童 套 裝台 灣 製 薄 長 袖 居家 套裝 魔法
# 997             高密尼龍後背包中型                  高密 尼龍 後 背包 中型
# 998               開口可調節戒指                     開口 可 調節 戒指
# 999               女排汗快干恤黑                    女排 汗 快干 恤 黑
#
# [1000 rows x 4 columns]

# %%
dev_tr_sents_all = []
for i in range(len(tcn_clean['product_title_processed'])):
    try: dev_tr_sents_all.append(translate(tcn_clean['product_title_processed'][i]))
    except: dev_tr_sents_all.append(np.nan)

# %%
tcn_clean['prediction']= dev_tr_sents_all

# %%
tcn_clean.drop('split', axis=1, inplace = True)
tcn_clean
# Out:
#                                                   text   product_title_clean  \
# 0                  OPPO A75 A75s A73 手机壳 软壳 挂绳壳 大眼兔硅胶壳        手机壳软壳挂绳壳大眼兔硅胶壳
# 1                                  SOFT 99 鍍膜車蠟(強力撥水型)             鍍膜車蠟強力撥水型
# 2                                       低糖芒果乾 250g 臻御行              低糖芒果乾臻御行
# 3    ＊小徑文化＊日本進口ROUND TOP space craft - diamond (SC-...              小徑文化日本進口
# 4            Hello Kitty 凱蒂貓 KITTY 涼鞋 童鞋 白/紅色 小童 no739          凱蒂貓涼鞋童鞋白紅色小童
# 5                      雷鳥 LT-234 日式木紋桌墊 45 x 60 cm / 片             雷鳥日式木紋桌墊片
# 6                                       狂砂小子DVD VOL-08                  狂砂小子
# 7                    ANACOMDA 巨蟒 T1 泰坦系列 120GB SSD固態硬碟            巨蟒泰坦系列固態硬碟
# 8                          iFairies 單肩斜背包側背包肩背包【49146】           單肩斜背包側背包肩背包
# 9                                      大雪山農場 山苦瓜茶20包/盒           大雪山農場山苦瓜茶包盒
# 10                                        高露潔 雙效潔淨牙刷單支           高露潔雙效潔淨牙刷單支
# 19           新品 時 尚可 愛寶寶繡 花連 衣裙 洋裝
# 20       客制化 泡泡 气囊 气垫 手机 支架 捕梦网 羽毛
# 21                 機器 人 印花 尼龍手 拿 包
# 22                 伊玛 公升 不锈钢 快 煮 壶
# 23                               送
# 24        日系 羊毛 混紡 保暖 堆堆 帽貝雷帽 毛線 帽
# 25                日本 芝 研植萃 皇后 化妝水款
# 26    德爾斐 神諭 繁體 中文版 高雄 龐奇 桌遊 新 天鵝堡
# 27                印尼 拉茶 包可 超取 峇 里島
# 28                教育 之友 成人 舒壓 著色 本
# 29               破盤 出清 短褲 顯瘦 休閒 熱褲
# ..                             ...
# 970                     耐吉高階 慢跑鞋 女
# 971                    達墨 雙車 用 充電器
# 972              純 鈦 兒童 湯匙 叉子 鈦 餐具
# 973                   多功能 鞋 深绿色 男鞋
# 974                 理優 英文 拼字 釘珠 上衣
# 975              白 金牌 可 調式 鋼筆 用 墨水
# 976             真皮 女用 小 手提 斜 背二用 包
# 977          多功能 觸摸 自行 車單 車腳 踏車 前包
# 978                透氣 網紗 閃 鑽 懶人鞋 藍
# 979                       鋯 石流 蘇耳環
# 980                       泰勒 絲手 機殼
# 981                美國 交通 系列 噗 噗車 藍
# 982       光華二聯 直式 非 碳紙 複 寫 估價 本入 包
# 983                 全 白色 袜套 复古 休闲鞋
# 984               紐頓 成犬 雞肉 南瓜 寶羅寵品
# 985                   三層 烤 漆 沖 孔鐵架
# 986            三麗鷗 指環扣 手機 支架 大頭 系列
# 987              學院 風百搭蕾 絲花邊 抽繩 短褲
# 988           側 背包 斜 背包 真皮 菱格 包包 包
# 989               自然 補給 膠原 玫 肌凍 飲瓶
# 990                        桐木 砂 玫瑰
# 991  冰雪 奇緣 白雪 森林 藍 卡通 睡袋 台 灣 製 迪士尼
# 992                     潔保 公共 排椅 組
# 993           加拿大 收納箱 兔子 台灣 授權 代理商
# 994           力 大牌 橫式 板 夾顏色 隨機 出貨個
# 995           撕破 乐趣 独特 风格 中直 筒 牛仔裤
# 996     兒童 套 裝台 灣 製 薄 長 袖 居家 套裝 魔法
# 997                  高密 尼龍 後 背包 中型
# 998                     開口 可 調節 戒指
# 999                    女排 汗 快干 恤 黑
#
#                                             prediction
# 0            oppo phone case soft rabbit silicone case
# 1               soft coating car wax strong water watt
# 2                     low sugar mango dry be the royal
# 3    the culture japan imported round top space cra...
# 4         hello kitty sandals shoes white red children
# 5    thunderbird lt japanese wood grain table mat x...
# 6                                 the sand kid dvd vol
# 7               anacomda python titan series ssd drive
# 8         ifairies shoulder messenger bag shoulder bag
# 9          the farm mountain bitter gourd tea pack box
# 10                       colgate dual clean toothbrush
# 11              apieu color lip pencil matt silk satin
# 12               reese s away milan rose gold ball pen
# 13         finding nemo glass magnet dolly _ the beast
# 14                 natural licorice oval pumpkin seeds
# 15                          papago hd driving recorder
# 16                            ista izmir the mesh head
# 17   dot focus adidas essentials chest logo square ...
# 18             tassel solid thread moka one blue black
# 19              new fashion cute baby embroidery dress
# 20          bubble airbag cushion phone holder catcher
# 21                prada robot printed nylon clutch bag
# 22           imarflex litres stainless quick kettle ik
# 23                  casio ex selfie camera free tescom
# 24         japanese wool blend warm pile cap beret hat
# 25                  japan azzeen planting queen lotion
# 26   de oracle the oracle of delphi from kaohsiung ...
# 27   max tea indonesia pull tea pack women bali island
# 28   educational friends baby adult thai coloring book
# 29   broken plate casual shorts slim casual hot pan...
# ..                                                 ...
# 970  nike wmns nike air zoom pegasus high running s...
# 971        at ink topmore stone dual usb car charger a
# 972  keith pure titanium children spoon fork titani...
# 973  merrell moab fst gtx shoes dark green men s shoes
# 974                   liyo english spelling beaded top
# 975                 white gold adjustable pen ink inkm
# 976  genuine leather female small handbag crossbody...
# 977  multifunctional touch bicycle cycling bicycle ...
# 978       sunnyq breathable mesh shiny lazy shoes blue
# 979                    ifairies zircon tassel earrings
# 980  taylor silk taylor swift case sony compact pre...
# 981        american kid o traffic series puff car blue
# 982  brilliance ghn two straight non carbon multipl...
# 983               new balance white retro casual shoes
# 984  newton adult dogs chicken pumpkin kg paul pet ...
# 985                      three layer paint punch metal
# 986  sanrio ring buckle phone holder _ hello kitty ...
# 987                college wind lace drawstring shorts
# 988    side backpack oblique backpack leather tote bag
# 989  natural replenishment collagen rose muscle bev...
# 990                           paulownia wood sand rose
# 991  frozen snow forest blue cartoon sleeping bag d...
# 992                     clean keep cp public chair set
# 993  canada sprouts storage box rabbit taiwan autho...
# 994  power big abel working model clip color random...
# 995      hippored torn fun unique style straight jeans
# 996  kids set table bay thin long sleeve home suit ...
# 997  longchamp le pliage neo high density nylon bac...
# 998          ifairies opening adjustable ring ifairies
# 999      polarstar women sweat quick dry t shirt black
#
# [1000 rows x 4 columns]

# %%
tcn_clean['prediction'] = tcn_clean['prediction'].replace(r'^\s*$', np.NaN, regex=True) #removes empty strings or strings containing only spaces with NaN

# %%
tcn_clean.isna().sum()
# Out:
# text                        0
# product_title_clean         6
# product_title_processed     6
# prediction                 10
# dtype: int64

# %%
tcn_clean.loc[pd.isna(tcn_clean).any(1), :].index #check nan after translated rows indexes
# Out:
# Int64Index([260, 396, 505, 568, 593, 597, 626, 654, 820, 904], dtype='int64')

# %%
tr_nan_indexes = tcn_clean.loc[pd.isna(tcn_clean).any(1), :].index #stores nan indexes for later dev_en follow to drop nan rows as well
tr_nan_indexes
# Out:
# Int64Index([260, 396, 505, 568, 593, 597, 626, 654, 820, 904], dtype='int64')

# %%
tcn_clean = tcn_clean.dropna()
tcn_clean.isna().sum()
# Out:
# text                       0
# product_title_clean        0
# product_title_processed    0
# prediction                 0
# dtype: int64

# %%
tcn_clean.to_csv('./output/1_NMT_dev_output1.csv',index = False, encoding='utf_8_sig')

# %%
dev_tr_sents_all_df = pd.read_csv('./output/1_NMT_dev_output1.csv')

# %%
dev_tr_sents_all_df
# Out:
#                                                   text   product_title_clean  \
# 0                  OPPO A75 A75s A73 手机壳 软壳 挂绳壳 大眼兔硅胶壳        手机壳软壳挂绳壳大眼兔硅胶壳
# 1                     鍍膜車 蠟 強力 撥水型
# 2                      低糖 芒果乾 臻 御行
# 3                      小徑 文化 日本 進口
# 4                 凱蒂貓 涼鞋 童鞋 白紅色 小童
# 5                     雷鳥 日式 木紋 桌墊片
# 6                            狂砂 小子
# 7                   巨蟒 泰坦 系列 固態 硬碟
# 8                單肩 斜 背包 側 背包 肩 背包
# 9                 大雪山 農場 山 苦瓜 茶 包盒
# 10                  高露潔 雙效潔淨 牙刷 單支
# 11                              絲緞
# 12                 芮菲 客米蘭 玫瑰 金鋼 珠筆
# 13             海底 總動員 玻璃 磁鐵多莉款 野獸國
# 14                       甘草 瓜子 南瓜子
# 15                          行車 記錄器
# 16                      伊士 達 分濾 網頭
# 17             聚點 方形 方塊 灰 藍連帽 帽 男款
# 18              流蘇立體 縫線 莫卡 辛鞋 藍 黑色
# 19           新品 時 尚可 愛寶寶繡 花連 衣裙 洋裝
# 20       客制化 泡泡 气囊 气垫 手机 支架 捕梦网 羽毛
# 21                 機器 人 印花 尼龍手 拿 包
# 22                 伊玛 公升 不锈钢 快 煮 壶
# 23                               送
# 24        日系 羊毛 混紡 保暖 堆堆 帽貝雷帽 毛線 帽
# 25                日本 芝 研植萃 皇后 化妝水款
# 26    德爾斐 神諭 繁體 中文版 高雄 龐奇 桌遊 新 天鵝堡
# 27                印尼 拉茶 包可 超取 峇 里島
# 28                教育 之友 成人 舒壓 著色 本
# 29               破盤 出清 短褲 顯瘦 休閒 熱褲
# ..                             ...
# 960                     耐吉高階 慢跑鞋 女
# 961                    達墨 雙車 用 充電器
# 962              純 鈦 兒童 湯匙 叉子 鈦 餐具
# 963                   多功能 鞋 深绿色 男鞋
# 964                 理優 英文 拼字 釘珠 上衣
# 965              白 金牌 可 調式 鋼筆 用 墨水
# 966             真皮 女用 小 手提 斜 背二用 包
# 967          多功能 觸摸 自行 車單 車腳 踏車 前包
# 968                透氣 網紗 閃 鑽 懶人鞋 藍
# 969                       鋯 石流 蘇耳環
# 970                       泰勒 絲手 機殼
# 971                美國 交通 系列 噗 噗車 藍
# 972       光華二聯 直式 非 碳紙 複 寫 估價 本入 包
# 973                 全 白色 袜套 复古 休闲鞋
# 974               紐頓 成犬 雞肉 南瓜 寶羅寵品
# 975                   三層 烤 漆 沖 孔鐵架
# 976            三麗鷗 指環扣 手機 支架 大頭 系列
# 977              學院 風百搭蕾 絲花邊 抽繩 短褲
# 978           側 背包 斜 背包 真皮 菱格 包包 包
# 979               自然 補給 膠原 玫 肌凍 飲瓶
# 980                        桐木 砂 玫瑰
# 981  冰雪 奇緣 白雪 森林 藍 卡通 睡袋 台 灣 製 迪士尼
# 982                     潔保 公共 排椅 組
# 983           加拿大 收納箱 兔子 台灣 授權 代理商
# 984           力 大牌 橫式 板 夾顏色 隨機 出貨個
# 985           撕破 乐趣 独特 风格 中直 筒 牛仔裤
# 986     兒童 套 裝台 灣 製 薄 長 袖 居家 套裝 魔法
# 987                  高密 尼龍 後 背包 中型
# 988                     開口 可 調節 戒指
# 989                    女排 汗 快干 恤 黑
#
#                                             prediction
# 0            oppo phone case soft rabbit silicone case
# 1               soft coating car wax strong water watt
# 2                     low sugar mango dry be the royal
# 3    the culture japan imported round top space cra...
# 4         hello kitty sandals shoes white red children
# 5    thunderbird lt japanese wood grain table mat x...
# 6                                 the sand kid dvd vol
# 7               anacomda python titan series ssd drive
# 8         ifairies shoulder messenger bag shoulder bag
# 9          the farm mountain bitter gourd tea pack box
# 10                       colgate dual clean toothbrush
# 11              apieu color lip pencil matt silk satin
# 12               reese s away milan rose gold ball pen
# 13         finding nemo glass magnet dolly _ the beast
# 14                 natural licorice oval pumpkin seeds
# 15                          papago hd driving recorder
# 16                            ista izmir the mesh head
# 17   dot focus adidas essentials chest logo square ...
# 18             tassel solid thread moka one blue black
# 19              new fashion cute baby embroidery dress
# 20          bubble airbag cushion phone holder catcher
# 21                prada robot printed nylon clutch bag
# 22           imarflex litres stainless quick kettle ik
# 23                  casio ex selfie camera free tescom
# 24         japanese wool blend warm pile cap beret hat
# 25                  japan azzeen planting queen lotion
# 26   de oracle the oracle of delphi from kaohsiung ...
# 27   max tea indonesia pull tea pack women bali island
# 28   educational friends baby adult thai coloring book
# 29   broken plate casual shorts slim casual hot pan...
# ..                                                 ...
# 960  nike wmns nike air zoom pegasus high running s...
# 961        at ink topmore stone dual usb car charger a
# 962  keith pure titanium children spoon fork titani...
# 963  merrell moab fst gtx shoes dark green men s shoes
# 964                   liyo english spelling beaded top
# 965                 white gold adjustable pen ink inkm
# 966  genuine leather female small handbag crossbody...
# 967  multifunctional touch bicycle cycling bicycle ...
# 968       sunnyq breathable mesh shiny lazy shoes blue
# 969                    ifairies zircon tassel earrings
# 970  taylor silk taylor swift case sony compact pre...
# 971        american kid o traffic series puff car blue
# 972  brilliance ghn two straight non carbon multipl...
# 973               new balance white retro casual shoes
# 974  newton adult dogs chicken pumpkin kg paul pet ...
# 975                      three layer paint punch metal
# 976  sanrio ring buckle phone holder _ hello kitty ...
# 977                college wind lace drawstring shorts
# 978    side backpack oblique backpack leather tote bag
# 979  natural replenishment collagen rose muscle bev...
# 980                           paulownia wood sand rose
# 981  frozen snow forest blue cartoon sleeping bag d...
# 982                     clean keep cp public chair set
# 983  canada sprouts storage box rabbit taiwan autho...
# 984  power big abel working model clip color random...
# 985      hippored torn fun unique style straight jeans
# 986  kids set table bay thin long sleeve home suit ...
# 987  longchamp le pliage neo high density nylon bac...
# 988          ifairies opening adjustable ring ifairies
# 989      polarstar women sweat quick dry t shirt black
#
# [990 rows x 4 columns]

# %%
# !pip install sacrebleu

# %%
import sacrebleu

# %%
dev_en_sents = en_clean.drop(tr_nan_indexes) # dropping same set of indexes as dev_tr for bleu scorer to match

# %%
refs = [dev_en_sents['translation_output']]
sys = dev_tr_sents_all_df['prediction']
bleu = sacrebleu.corpus_bleu(sys, refs, lowercase=True)
print(bleu.precisions)
# Out:
# [95.45272167981811, 95.28287343918606, 95.27014735310169, 95.30245956126745]
