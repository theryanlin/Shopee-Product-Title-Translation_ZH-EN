# %%
import pandas as pd
import numpy as np
import re
from google.colab import drive
drive.mount('/content/drive')

train = pd.read_csv('/content/drive/My Drive/Shopee-Product-Title-Translation_ZH-EN/datasets/train_en.csv')
dev = pd.read_csv('/content/drive/My Drive/Shopee-Product-Title-Translation_ZH-EN/datasets/dev_en.csv')
# Out:
# Mounted at /content/drive

# %%
train.head()
# Out:
#                                        product_title                category
# 0  Recollections Color Splash Clear Stamps & Stencil    Hobbies & Stationery
# 1                          soap,lotion scrub set 400  Health & Personal Care
# 2       Spigen Galaxy S10e Case Tough Armor Gunmetal      Mobile Accessories
# 3                         Acrylic Lanalon Bright Red    Hobbies & Stationery
# 4                 303 FLAT SHEET/Blanket 100% cotton           Home & Living

# %%
dev.head()
# Out:
#                                   translation_output
# 0  Oppo A75 A75S A73 Phone Case Soft Rabbit Silic...
# 1          SOFT 99 Coating Car Wax Strong Water Watt
# 2              Low Sugar Mango Dry 250g Be The Royal
# 3  * the culture Japan Imported Round Top Space C...
# 4  Hello Kitty Sandals Shoes White/Red Children n...

# %% [markdown]
# 1. punctuation removal
# 2. numbers removal
# 3. emoji/special characters removal
# 4. transfer to lowercase
# 5. tokenization
# 6. stopwords removal (ignore)

# %%
def processor(text):
    try:
      text = re.sub(r'[^\w]', ' ', text.lower()) # remove non english words, special characters
      text = re.sub(r'\b\w*[\d]+\w*\b', ' ', text) # remove non digits
      text = ' '.join(text.split()) # remove extra spaces
    except:
      pass
    return text

# %%
train['processed_title'] = train['product_title'].apply(processor)
dev['processed_title'] = dev['translation_output'].apply(processor)

# %%
train
# Out:
#                                             product_title  \
# 0       Recollections Color Splash Clear Stamps & Stencil
# 1                               soap,lotion scrub set 400
# 2            Spigen Galaxy S10e Case Tough Armor Gunmetal
# 3                              Acrylic Lanalon Bright Red
# 4                      303 FLAT SHEET/Blanket 100% cotton
# ...                                                   ...
# 499995                       rocker arm roller racing mio
# 499996                            Secosana (preloved bag)
# 499997                                            jag bag
# 499998  Baby wipes 15 sheets (Alcohol and Paraben Free...
# 499999                  PRE-LOVED ORIGINAL GREEN FINO BAG
#
#                       category  \
# 0         Hobbies & Stationery
# 1       Health & Personal Care
# 2           Mobile Accessories
# 3         Hobbies & Stationery
# 4                Home & Living
# ...                        ...
# 499995                  Motors
# ...

# %%
train.to_csv('/content/drive/My Drive/Shopee-Product-Title-Translation_ZH-EN/preprocessed/cleaned_train_en.csv', index=False)
dev.to_csv('/content/drive/My Drive/Shopee-Product-Title-Translation_ZH-EN/preprocessed/cleaned_dev_en.csv', index=False)
